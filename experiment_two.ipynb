# %% [markdown]
# # Experiment One
# All available training data

# %% [markdown]
# ## Augmentation of dataset

# %%
EXP_NUM=2

# %%
import tensorflow as tf
from pathlib import Path


def augment_in_place_orig_plus_4_no_resize(
    root: str | Path,
    *,
    allowed_ext: tuple[str, ...] = (".jpg", ".jpeg", ".png", ".webp", ".bmp", ".tif", ".tiff"),
    jpeg_quality: int = 95,
    suffix_sep: str = "__",
) -> dict[str, int]:
    """
    Dla każdego obrazu w root/<class_name>/:
      - NIE zmienia wymiarów obrazu
      - NIE usuwa oryginału
      - dodaje 4 nowe obrazy w tym samym folderze:
        flip, rot90, bright, contrast

    Zwraca: dict {class_name: liczba_dodanych_obrazów}
    """
    root = Path(root)
    allowed = {e.lower() for e in allowed_ext}
    stats: dict[str, int] = {}

    def load_image(path: Path) -> tf.Tensor:
        b = tf.io.read_file(str(path))
        # decode_image zachowuje oryginalny rozmiar
        img = tf.image.decode_image(b, channels=3, expand_animations=False)
        img = tf.cast(tf.clip_by_value(img, 0, 255), tf.uint8)
        return img

    def save_jpeg(img_uint8: tf.Tensor, out_path: Path):
        jpeg = tf.io.encode_jpeg(img_uint8, quality=jpeg_quality)
        tf.io.write_file(str(out_path), jpeg)

    # 4 augmentacje zachowujące rozmiar
    def aug_flip(img):      return tf.image.flip_left_right(img)
    def aug_rot90(img):     return tf.image.rot90(img, k=1)   # 90°
    def aug_bright(img):
        x = tf.image.adjust_brightness(tf.cast(img, tf.float32), 0.15 * 255.0)
        return tf.cast(tf.clip_by_value(x, 0, 255), tf.uint8)
    def aug_contrast(img):
        x = tf.image.adjust_contrast(tf.cast(img, tf.float32), 1.2)
        return tf.cast(tf.clip_by_value(x, 0, 255), tf.uint8)

    variants = [
        ("flip", aug_flip),
        ("rot90", aug_rot90),
        ("bright", aug_bright),
        ("contrast", aug_contrast),
    ]

    for class_dir in [p for p in root.iterdir() if p.is_dir()]:
        class_name = class_dir.name

        originals = [
            p for p in class_dir.iterdir()
            if p.is_file()
            and p.suffix.lower() in allowed
            and suffix_sep not in p.stem
        ]

        added = 0
        for p in originals:
            img = load_image(p)

            for tag, fn in variants:
                out_path = class_dir / f"{p.stem}{suffix_sep}{tag}.jpg"
                if out_path.exists():
                    continue
                save_jpeg(fn(img), out_path)
                added += 1

        stats[class_name] = added

    return stats

# %%
stats = augment_in_place_orig_plus_4_no_resize(
    root=f"data/E{EXP_NUM}/train",
)

print(stats)
# Out:
# {'black_morel': 92, 'bitter_bolete': 92, 'curry_milkcap': 92, 'destroying_angel': 92, 'brown_birch_bolete': 92}

# %% [markdown]
# ## Importing datasets

# %%
import tensorflow as tf
from pathlib import Path
import os

TRAIN_DIR = f"data/E{EXP_NUM}/train"
TEST_DIR = "data/test"

IMG_SIZE = (512, 512)
BATCH_SIZE = 8
SEED = 42

# 4 augmentacje (takie same dla AlexNet i ResNet50)
AUG_SUFFIX_SEP = "__"
AUG_TAGS = ["flip", "rot90", "bright", "contrast"]

def _list_augmented_files(root: str | Path, tag: str, allowed_ext=(".jpg",".jpeg",".png",".webp",".bmp",".tif",".tiff")):
    root = Path(root)
    allowed = {e.lower() for e in allowed_ext}
    files, labels = [], []
    class_names = sorted([p.name for p in root.iterdir() if p.is_dir()])
    class_to_idx = {c:i for i,c in enumerate(class_names)}
    for c in class_names:
        class_dir = root / c
        for p in class_dir.iterdir():
            if not p.is_file():
                continue
            if p.suffix.lower() not in allowed:
                continue
            # tylko dane zaugmentowane daną augmentacją (bez oryginałów i bez innych augmentacji)
            if f"{AUG_SUFFIX_SEP}{tag}" not in p.stem:
                continue
            files.append(str(p))
            labels.append(class_to_idx[c])
    return files, labels, class_names

def _decode_and_resize(path, label):
    img = tf.io.read_file(path)
    img = tf.image.decode_image(img, channels=3, expand_animations=False)
    img.set_shape([None, None, 3])
    img = tf.image.resize(img, IMG_SIZE, method="bilinear")
    img = tf.cast(img, tf.float32)
    return img, label

def make_train_ds_for_aug(tag: str, shuffle=True):
    files, labels, class_names = _list_augmented_files(TRAIN_DIR, tag)
    if len(files) == 0:
        raise ValueError(f"Brak plików treningowych dla augmentacji '{tag}'. Upewnij się, że augmentacje zostały wygenerowane w {TRAIN_DIR}.")
    ds = tf.data.Dataset.from_tensor_slices((files, labels))
    if shuffle:
        ds = ds.shuffle(buffer_size=min(len(files), 2048), seed=SEED, reshuffle_each_iteration=True)
    ds = ds.map(_decode_and_resize, num_parallel_calls=tf.data.AUTOTUNE)
    ds = ds.batch(BATCH_SIZE).prefetch(tf.data.AUTOTUNE)
    return ds, class_names

# Test (bez augmentacji)
test_ds = tf.keras.utils.image_dataset_from_directory(
    TEST_DIR,
    image_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    shuffle=False,
    label_mode="int"
).prefetch(tf.data.AUTOTUNE)

print("Ustawienia:")
print(" IMG_SIZE   =", IMG_SIZE)
print(" BATCH_SIZE =", BATCH_SIZE)
print(" AUG_TAGS   =", AUG_TAGS)
# Out:
# Found 20 files belonging to 5 classes.
# Ustawienia:
#  IMG_SIZE   = (512, 512)
#  BATCH_SIZE = 8
#  AUG_TAGS   = ['flip', 'rot90', 'bright', 'contrast']

# %% [markdown]
# ## AlexNet512

# %%
import tensorflow as tf

def lrn(x, depth_radius=2, bias=1.0, alpha=1e-4, beta=0.75):
    return tf.nn.local_response_normalization(
        x, depth_radius=depth_radius, bias=bias, alpha=alpha, beta=beta
    )

def build_alexnet_512(input_shape=(512, 512, 3), num_classes=5, dropout=0.2):
    inputs = tf.keras.Input(shape=input_shape)
    x = tf.keras.layers.Rescaling(1./255)(inputs)

    # Conv1
    x = tf.keras.layers.Conv2D(96, 11, strides=4, padding="valid", activation="relu")(x)
    x = tf.keras.layers.Lambda(lrn)(x)
    x = tf.keras.layers.MaxPooling2D(3, strides=2)(x)

    # Conv2
    x = tf.keras.layers.Conv2D(256, 5, padding="same", activation="relu")(x)
    x = tf.keras.layers.Lambda(lrn)(x)
    x = tf.keras.layers.MaxPooling2D(3, strides=2)(x)

    # Conv3-5
    x = tf.keras.layers.Conv2D(384, 3, padding="same", activation="relu")(x)
    x = tf.keras.layers.Conv2D(384, 3, padding="same", activation="relu")(x)
    x = tf.keras.layers.Conv2D(256, 3, padding="same", activation="relu")(x)
    x = tf.keras.layers.MaxPooling2D(3, strides=2)(x)

    # Zamiast Flatten (żeby 512x512 nie zabiło parametrów)
    x = tf.keras.layers.GlobalAveragePooling2D()(x)

    # FC (AlexNet-like)
    x = tf.keras.layers.Dense(4096, activation="relu")(x)
    x = tf.keras.layers.Dropout(dropout)(x)
    x = tf.keras.layers.Dense(4096, activation="relu")(x)
    x = tf.keras.layers.Dropout(dropout)(x)

    outputs = tf.keras.layers.Dense(num_classes, activation="softmax")(x)
    return tf.keras.Model(inputs, outputs, name="alexnet_512")

# %% [markdown]
# ## Residual Network (ResNet50)

# %%
import tensorflow as tf

def build_resnet50_512(num_classes: int, input_shape=(512, 512, 3), train_base: bool = False):
    inputs = tf.keras.Input(shape=input_shape)

    # ResNet50 oczekuje preprocess_input
    x = tf.keras.applications.resnet50.preprocess_input(inputs)

    base = tf.keras.applications.ResNet50(
        include_top=False,
        weights="imagenet",
        input_tensor=x,
        pooling=None
    )
    base.trainable = train_base  # False = zamrożony backbone

    x = base.output
    x = tf.keras.layers.GlobalAveragePooling2D()(x)
    x = tf.keras.layers.Dropout(0.2)(x)
    outputs = tf.keras.layers.Dense(num_classes, activation="softmax")(x)

    model = tf.keras.Model(inputs, outputs, name="resnet50_512")
    return model

# %% [markdown]
# ## Trening 8 modeli (AlexNet i ResNet50 × 4 augmentacje)
#
# - Uczymy łącznie **8 modeli**: 4×AlexNet512 i 4×ResNet50.
# - Dla obu architektur używamy **tych samych 4 augmentacji**: `flip`, `rot90`, `bright`, `contrast`.
# - **Modele uczą się wyłącznie na danych zaugmentowanych** (oryginały są pomijane w `train_ds`).
# - Zbiór testowy pozostaje bez augmentacji.

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
from pathlib import Path

Path("models").mkdir(parents=True, exist_ok=True)

def train_and_evaluate(model_name: str, aug_tag: str):
    train_ds, class_names = make_train_ds_for_aug(aug_tag, shuffle=True)
    num_classes = len(class_names)

    if model_name == "alexnet":
        model = build_alexnet_512(input_shape=(*IMG_SIZE, 3), num_classes=num_classes, dropout=0.2)
        model.compile(
            optimizer=tf.keras.optimizers.SGD(learning_rate=0.01, momentum=0.9),
            loss=tf.keras.losses.SparseCategoricalCrossentropy(),
            metrics=[tf.keras.metrics.SparseCategoricalAccuracy()],
        )
        epochs = 100
    elif model_name == "resnet50":
        model = build_resnet50_512(num_classes=num_classes, input_shape=(*IMG_SIZE, 3), train_base=False)
        model.compile(
            optimizer=tf.keras.optimizers.Adam(learning_rate=1e-3),
            loss=tf.keras.losses.SparseCategoricalCrossentropy(),
            metrics=[tf.keras.metrics.SparseCategoricalAccuracy()],
        )
        epochs = 10
    else:
        raise ValueError("Nieznany model_name")

    print(f"\n=== Trenowanie: {model_name} | augmentacja: {aug_tag} | klasy: {num_classes} ===")
    history = model.fit(train_ds, epochs=epochs, verbose=1)

    weights_path = f"models/e{EXP_NUM}_{model_name}_{aug_tag}.weights.h5"
    model.save_weights(weights_path)
    print("Zapisano wagi:", weights_path)

    test_loss, test_acc = model.evaluate(test_ds, verbose=1)

    # predykcje + macierz pomyłek
    y_true = np.concatenate([y.numpy() for _, y in test_ds], axis=0)
    y_pred = np.argmax(model.predict(test_ds, verbose=0), axis=1)
    cm = confusion_matrix(y_true, y_pred)

    fig, ax = plt.subplots(figsize=(8, 8))
    disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=class_names)
    disp.plot(ax=ax, cmap="Blues", colorbar=True, xticks_rotation=45)
    plt.title(f"Confusion Matrix | {model_name} | aug={aug_tag}")
    plt.tight_layout()
    plt.show()

    return {
        "model": model_name,
        "augmentation": aug_tag,
        "epochs": epochs,
        "test_loss": float(test_loss),
        "test_acc": float(test_acc),
        "weights_path": weights_path,
        "history": history.history,
        "class_names": class_names,
        "confusion_matrix": cm,
    }

results = []
for aug_tag in AUG_TAGS:
    # 4 modele AlexNet (po 1 na augmentację)
    results.append(train_and_evaluate("alexnet", aug_tag))

for aug_tag in AUG_TAGS:
    # 4 modele ResNet50 (po 1 na augmentację)
    results.append(train_and_evaluate("resnet50", aug_tag))

# Podsumowanie
import pandas as pd
summary = pd.DataFrame([{
    "model": r["model"],
    "augmentation": r["augmentation"],
    "epochs": r["epochs"],
    "test_acc": r["test_acc"],
    "test_loss": r["test_loss"],
    "weights_path": r["weights_path"],
} for r in results]).sort_values(["model", "augmentation"])

summary
# Out:
# === Trenowanie: alexnet | augmentacja: flip | klasy: 5 ===
# Epoch 1/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 11s 474ms/step - loss: 1.6110 - sparse_categorical_accuracy: 0.1336
# Epoch 2/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 2s 95ms/step - loss: 1.6093 - sparse_categorical_accuracy: 0.2699
# Epoch 3/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 78ms/step - loss: 1.6067 - sparse_categorical_accuracy: 0.2369
# Epoch 4/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 70ms/step - loss: 1.5999 - sparse_categorical_accuracy: 0.2008
# Epoch 5/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 69ms/step - loss: 1.5873 - sparse_categorical_accuracy: 0.2701
# Epoch 6/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - loss: 1.5668 - sparse_categorical_accuracy: 0.3308
# Epoch 7/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 69ms/step - loss: 1.5415 - sparse_categorical_accuracy: 0.2593
# Epoch 8/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 69ms/step - loss: 1.4743 - sparse_categorical_accuracy: 0.3144
# Epoch 9/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 69ms/step - loss: 1.3843 - sparse_categorical_accuracy: 0.3868
# Epoch 10/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 69ms/step - loss: 1.4274 - sparse_categorical_accuracy: 0.4488
# Epoch 11/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 69ms/step - loss: 1.5849 - sparse_categorical_accuracy: 0.2205
# Epoch 12/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 92ms/step - loss: 1.4605 - sparse_categorical_accuracy: 0.4278
# Epoch 13/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 86ms/step - loss: 1.4577 - sparse_categorical_accuracy: 0.3642
# Epoch 14/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 2s 68ms/step - loss: 1.4691 - sparse_categorical_accuracy: 0.3436
# Epoch 15/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - loss: 1.6676 - sparse_categorical_accuracy: 0.2004
# Epoch 16/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - loss: 1.6299 - sparse_categorical_accuracy: 0.1709
# Epoch 17/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - loss: 1.5987 - sparse_categorical_accuracy: 0.1822
# Epoch 18/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - loss: 1.6091 - sparse_categorical_accuracy: 0.1820
# Epoch 19/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - loss: 1.6123 - sparse_categorical_accuracy: 0.1294
# Epoch 20/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - loss: 1.6077 - sparse_categorical_accuracy: 0.2279
# Epoch 21/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 69ms/step - loss: 1.6067 - sparse_categorical_accuracy: 0.2315
# Epoch 22/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 2s 92ms/step - loss: 1.6093 - sparse_categorical_accuracy: 0.1617
# Epoch 23/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 2s 67ms/step - loss: 1.6054 - sparse_categorical_accuracy: 0.2539
# Epoch 24/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - loss: 1.5990 - sparse_categorical_accuracy: 0.2848
# Epoch 25/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - loss: 1.5721 - sparse_categorical_accuracy: 0.2815
# Epoch 26/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - loss: 1.6051 - sparse_categorical_accuracy: 0.1890
# Epoch 27/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - loss: 1.6209 - sparse_categorical_accuracy: 0.1156
# Epoch 28/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - loss: 1.6146 - sparse_categorical_accuracy: 0.0997
# Epoch 29/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - loss: 1.6109 - sparse_categorical_accuracy: 0.2242
# Epoch 30/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - loss: 1.6102 - sparse_categorical_accuracy: 0.2262
# Epoch 31/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 2s 99ms/step - loss: 1.6116 - sparse_categorical_accuracy: 0.1558
# Epoch 32/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 2s 65ms/step - loss: 1.6079 - sparse_categorical_accuracy: 0.2701
# Epoch 33/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - loss: 1.6037 - sparse_categorical_accuracy: 0.2512
# Epoch 34/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - loss: 1.6136 - sparse_categorical_accuracy: 0.1594
# Epoch 35/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - loss: 1.6154 - sparse_categorical_accuracy: 0.1301
# Epoch 36/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - loss: 1.6071 - sparse_categorical_accuracy: 0.2640
# Epoch 37/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - loss: 1.6069 - sparse_categorical_accuracy: 0.2286
# Epoch 38/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - loss: 1.6133 - sparse_categorical_accuracy: 0.1554
# Epoch 39/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - loss: 1.6060 - sparse_categorical_accuracy: 0.2103
# Epoch 40/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 2s 86ms/step - loss: 1.6138 - sparse_categorical_accuracy: 0.1482
# Epoch 41/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 89ms/step - loss: 1.6124 - sparse_categorical_accuracy: 0.1725
# Epoch 42/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - loss: 1.5859 - sparse_categorical_accuracy: 0.2829
# Epoch 43/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - loss: 1.5856 - sparse_categorical_accuracy: 0.2446
# Epoch 44/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - loss: 1.5131 - sparse_categorical_accuracy: 0.3005
# Epoch 45/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - loss: 1.5396 - sparse_categorical_accuracy: 0.1891
# Epoch 46/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - loss: 1.4295 - sparse_categorical_accuracy: 0.3738
# Epoch 47/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - loss: 1.6539 - sparse_categorical_accuracy: 0.1613
# Epoch 48/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - loss: 1.6274 - sparse_categorical_accuracy: 0.2149
# Epoch 49/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - loss: 1.6279 - sparse_categorical_accuracy: 0.1592
# Epoch 50/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - loss: 1.6044 - sparse_categorical_accuracy: 0.1878
# Epoch 51/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 2s 92ms/step - loss: 1.6068 - sparse_categorical_accuracy: 0.2168
# Epoch 52/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 2s 64ms/step - loss: 1.6124 - sparse_categorical_accuracy: 0.2217
# Epoch 53/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - loss: 1.6178 - sparse_categorical_accuracy: 0.1633
# Epoch 54/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - loss: 1.6074 - sparse_categorical_accuracy: 0.2159
# Epoch 55/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - loss: 1.6097 - sparse_categorical_accuracy: 0.2211
# Epoch 56/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - loss: 1.6100 - sparse_categorical_accuracy: 0.1672
# Epoch 57/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - loss: 1.6149 - sparse_categorical_accuracy: 0.1338
# Epoch 58/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 64ms/step - loss: 1.6156 - sparse_categorical_accuracy: 0.1824
# Epoch 59/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - loss: 1.6137 - sparse_categorical_accuracy: 0.1740
# Epoch 60/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 2s 101ms/step - loss: 1.6107 - sparse_categorical_accuracy: 0.1795
# Epoch 61/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 75ms/step - loss: 1.6089 - sparse_categorical_accuracy: 0.2030
# Epoch 62/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - loss: 1.6106 - sparse_categorical_accuracy: 0.2624
# Epoch 63/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - loss: 1.6082 - sparse_categorical_accuracy: 0.2604
# Epoch 64/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - loss: 1.6114 - sparse_categorical_accuracy: 0.1771
# Epoch 65/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - loss: 1.6153 - sparse_categorical_accuracy: 0.1582
# Epoch 66/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - loss: 1.6110 - sparse_categorical_accuracy: 0.2169
# Epoch 67/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - loss: 1.6090 - sparse_categorical_accuracy: 0.2117
# Epoch 68/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - loss: 1.6075 - sparse_categorical_accuracy: 0.2333
# Epoch 69/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - loss: 1.6136 - sparse_categorical_accuracy: 0.1496
# Epoch 70/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 86ms/step - loss: 1.6113 - sparse_categorical_accuracy: 0.1856
# Epoch 71/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 89ms/step - loss: 1.6123 - sparse_categorical_accuracy: 0.2653
# Epoch 72/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - loss: 1.6016 - sparse_categorical_accuracy: 0.2561
# Epoch 73/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - loss: 1.6084 - sparse_categorical_accuracy: 0.2192
# Epoch 74/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - loss: 1.6144 - sparse_categorical_accuracy: 0.1896
# Epoch 75/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - loss: 1.6118 - sparse_categorical_accuracy: 0.1476
# Epoch 76/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - loss: 1.6080 - sparse_categorical_accuracy: 0.1997
# Epoch 77/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - loss: 1.6142 - sparse_categorical_accuracy: 0.1372
# Epoch 78/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - loss: 1.6088 - sparse_categorical_accuracy: 0.2704
# Epoch 79/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - loss: 1.6105 - sparse_categorical_accuracy: 0.1416
# Epoch 80/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - loss: 1.6126 - sparse_categorical_accuracy: 0.1396
# Epoch 81/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 2s 97ms/step - loss: 1.6180 - sparse_categorical_accuracy: 0.1912
# Epoch 82/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 72ms/step - loss: 1.6123 - sparse_categorical_accuracy: 0.1251
# Epoch 83/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - loss: 1.6099 - sparse_categorical_accuracy: 0.1983
# Epoch 84/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - loss: 1.6106 - sparse_categorical_accuracy: 0.2351
# Epoch 85/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - loss: 1.6128 - sparse_categorical_accuracy: 0.1687
# Epoch 86/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - loss: 1.6117 - sparse_categorical_accuracy: 0.2204
# Epoch 87/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - loss: 1.6138 - sparse_categorical_accuracy: 0.1895
# Epoch 88/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - loss: 1.6131 - sparse_categorical_accuracy: 0.2375
# Epoch 89/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - loss: 1.6109 - sparse_categorical_accuracy: 0.2064
# Epoch 90/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - loss: 1.6105 - sparse_categorical_accuracy: 0.1944
# Epoch 91/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 83ms/step - loss: 1.6095 - sparse_categorical_accuracy: 0.2149
# Epoch 92/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 92ms/step - loss: 1.6082 - sparse_categorical_accuracy: 0.2135
# Epoch 93/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 2s 66ms/step - loss: 1.6129 - sparse_categorical_accuracy: 0.1608
# Epoch 94/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - loss: 1.6128 - sparse_categorical_accuracy: 0.1541
# Epoch 95/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - loss: 1.6119 - sparse_categorical_accuracy: 0.2263
# Epoch 96/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - loss: 1.6169 - sparse_categorical_accuracy: 0.1534
# Epoch 97/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - loss: 1.6082 - sparse_categorical_accuracy: 0.2143
# Epoch 98/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - loss: 1.6067 - sparse_categorical_accuracy: 0.2457
# Epoch 99/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 64ms/step - loss: 1.6084 - sparse_categorical_accuracy: 0.2147
# Epoch 100/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - loss: 1.6118 - sparse_categorical_accuracy: 0.1405
# Zapisano wagi: models/e2_alexnet_flip.weights.h5
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 371ms/step - loss: 1.6195 - sparse_categorical_accuracy: 0.1625
# === Trenowanie: alexnet | augmentacja: rot90 | klasy: 5 ===
# Epoch 1/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 8s 250ms/step - loss: 1.6109 - sparse_categorical_accuracy: 0.1151
# Epoch 2/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 71ms/step - loss: 1.6094 - sparse_categorical_accuracy: 0.2694
# Epoch 3/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 92ms/step - loss: 1.6080 - sparse_categorical_accuracy: 0.2391
# Epoch 4/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 2s 67ms/step - loss: 1.6045 - sparse_categorical_accuracy: 0.2181
# Epoch 5/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - loss: 1.5899 - sparse_categorical_accuracy: 0.2949
# Epoch 6/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - loss: 1.5655 - sparse_categorical_accuracy: 0.2817
# Epoch 7/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - loss: 1.6174 - sparse_categorical_accuracy: 0.1904
# Epoch 8/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - loss: 1.6032 - sparse_categorical_accuracy: 0.1997
# Epoch 9/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - loss: 1.5943 - sparse_categorical_accuracy: 0.2478
# Epoch 10/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - loss: 1.5780 - sparse_categorical_accuracy: 0.3360
# Epoch 11/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 69ms/step - loss: 1.5142 - sparse_categorical_accuracy: 0.2823
# Epoch 12/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 95ms/step - loss: 1.9398 - sparse_categorical_accuracy: 0.1508
# Epoch 13/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 2s 67ms/step - loss: 1.6202 - sparse_categorical_accuracy: 0.2169
# Epoch 14/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - loss: 1.6103 - sparse_categorical_accuracy: 0.1959
# Epoch 15/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - loss: 1.6081 - sparse_categorical_accuracy: 0.1833
# Epoch 16/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - loss: 1.6078 - sparse_categorical_accuracy: 0.1695
# Epoch 17/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - loss: 1.6058 - sparse_categorical_accuracy: 0.3226
# Epoch 18/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - loss: 1.6010 - sparse_categorical_accuracy: 0.3000
# Epoch 19/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - loss: 1.5970 - sparse_categorical_accuracy: 0.2162
# Epoch 20/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - loss: 1.5859 - sparse_categorical_accuracy: 0.2466
# Epoch 21/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 2s 99ms/step - loss: 1.5618 - sparse_categorical_accuracy: 0.2488
# Epoch 22/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 83ms/step - loss: 1.5090 - sparse_categorical_accuracy: 0.3849
# Epoch 23/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - loss: 1.4722 - sparse_categorical_accuracy: 0.2965
# Epoch 24/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - loss: 1.5950 - sparse_categorical_accuracy: 0.2949
# Epoch 25/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - loss: 1.4204 - sparse_categorical_accuracy: 0.3652
# Epoch 26/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - loss: 1.4143 - sparse_categorical_accuracy: 0.3139
# Epoch 27/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - loss: 1.4158 - sparse_categorical_accuracy: 0.2585
# Epoch 28/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - loss: 1.5696 - sparse_categorical_accuracy: 0.2309
# Epoch 29/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - loss: 1.5871 - sparse_categorical_accuracy: 0.2477
# Epoch 30/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - loss: 1.4075 - sparse_categorical_accuracy: 0.3932
# Epoch 31/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 81ms/step - loss: 1.4820 - sparse_categorical_accuracy: 0.3826
# Epoch 32/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 2s 67ms/step - loss: 1.5512 - sparse_categorical_accuracy: 0.3113
# Epoch 33/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - loss: 1.3801 - sparse_categorical_accuracy: 0.3969
# Epoch 34/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - loss: 1.3614 - sparse_categorical_accuracy: 0.3777
# Epoch 35/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - loss: 1.4152 - sparse_categorical_accuracy: 0.2805
# Epoch 36/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - loss: 1.3254 - sparse_categorical_accuracy: 0.3783
# Epoch 37/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - loss: 1.2333 - sparse_categorical_accuracy: 0.4486
# Epoch 38/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - loss: 1.2311 - sparse_categorical_accuracy: 0.4080
# Epoch 39/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - loss: 1.2947 - sparse_categorical_accuracy: 0.4012
# Epoch 40/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 83ms/step - loss: 1.2996 - sparse_categorical_accuracy: 0.3603
# Epoch 41/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 2s 94ms/step - loss: 1.2061 - sparse_categorical_accuracy: 0.3857
# Epoch 42/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - loss: 1.1246 - sparse_categorical_accuracy: 0.5375
# Epoch 43/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - loss: 1.4875 - sparse_categorical_accuracy: 0.3563
# Epoch 44/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - loss: 1.5096 - sparse_categorical_accuracy: 0.3858
# Epoch 45/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - loss: 1.2926 - sparse_categorical_accuracy: 0.4466
# Epoch 46/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - loss: 1.2167 - sparse_categorical_accuracy: 0.5259
# Epoch 47/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - loss: 1.1569 - sparse_categorical_accuracy: 0.5359
# Epoch 48/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - loss: 1.0148 - sparse_categorical_accuracy: 0.5103
# Epoch 49/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - loss: 1.1489 - sparse_categorical_accuracy: 0.4449
# Epoch 50/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - loss: 1.0659 - sparse_categorical_accuracy: 0.5443
# Epoch 51/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 2s 93ms/step - loss: 0.9902 - sparse_categorical_accuracy: 0.5615
# Epoch 52/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 75ms/step - loss: 1.2589 - sparse_categorical_accuracy: 0.4456
# Epoch 53/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - loss: 1.0656 - sparse_categorical_accuracy: 0.5760
# Epoch 54/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - loss: 1.1776 - sparse_categorical_accuracy: 0.4170
# Epoch 55/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - loss: 1.0608 - sparse_categorical_accuracy: 0.5318
# Epoch 56/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - loss: 1.1170 - sparse_categorical_accuracy: 0.5742
# Epoch 57/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - loss: 1.2933 - sparse_categorical_accuracy: 0.4211
# Epoch 58/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - loss: 1.0707 - sparse_categorical_accuracy: 0.5803
# Epoch 59/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - loss: 1.0617 - sparse_categorical_accuracy: 0.6163
# Epoch 60/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - loss: 1.0181 - sparse_categorical_accuracy: 0.5627
# Epoch 61/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 2s 95ms/step - loss: 0.9778 - sparse_categorical_accuracy: 0.5038
# Epoch 62/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 2s 66ms/step - loss: 1.1467 - sparse_categorical_accuracy: 0.4537
# Epoch 63/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - loss: 0.9340 - sparse_categorical_accuracy: 0.6185
# Epoch 64/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - loss: 1.0768 - sparse_categorical_accuracy: 0.5476
# Epoch 65/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - loss: 0.9110 - sparse_categorical_accuracy: 0.5137
# Epoch 66/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - loss: 1.0944 - sparse_categorical_accuracy: 0.5298
# Epoch 67/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - loss: 0.9892 - sparse_categorical_accuracy: 0.5598
# Epoch 68/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - loss: 1.1743 - sparse_categorical_accuracy: 0.5061
# Epoch 69/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - loss: 1.1301 - sparse_categorical_accuracy: 0.4905
# Epoch 70/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 2s 94ms/step - loss: 1.1825 - sparse_categorical_accuracy: 0.5168
# Epoch 71/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 2s 67ms/step - loss: 1.1970 - sparse_categorical_accuracy: 0.4084
# Epoch 72/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - loss: 1.4269 - sparse_categorical_accuracy: 0.4119
# Epoch 73/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - loss: 0.8692 - sparse_categorical_accuracy: 0.5993
# Epoch 74/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - loss: 0.8538 - sparse_categorical_accuracy: 0.6247
# Epoch 75/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - loss: 0.8013 - sparse_categorical_accuracy: 0.6571
# Epoch 76/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - loss: 0.8196 - sparse_categorical_accuracy: 0.6280
# Epoch 77/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - loss: 0.8668 - sparse_categorical_accuracy: 0.6516
# Epoch 78/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - loss: 0.7945 - sparse_categorical_accuracy: 0.6946
# Epoch 79/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 82ms/step - loss: 0.7512 - sparse_categorical_accuracy: 0.6262
# Epoch 80/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 88ms/step - loss: 0.6345 - sparse_categorical_accuracy: 0.7379
# Epoch 81/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 2s 66ms/step - loss: 0.8182 - sparse_categorical_accuracy: 0.6681
# Epoch 82/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - loss: 1.1585 - sparse_categorical_accuracy: 0.4617
# Epoch 83/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - loss: 0.7764 - sparse_categorical_accuracy: 0.6424
# Epoch 84/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - loss: 0.7606 - sparse_categorical_accuracy: 0.6714
# Epoch 85/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - loss: 0.6310 - sparse_categorical_accuracy: 0.7555
# Epoch 86/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - loss: 0.8175 - sparse_categorical_accuracy: 0.6975
# Epoch 87/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - loss: 0.6991 - sparse_categorical_accuracy: 0.7044
# Epoch 88/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - loss: 0.7626 - sparse_categorical_accuracy: 0.6639
# Epoch 89/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 2s 96ms/step - loss: 0.9065 - sparse_categorical_accuracy: 0.5764
# Epoch 90/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 84ms/step - loss: 0.7201 - sparse_categorical_accuracy: 0.7112
# Epoch 91/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 2s 67ms/step - loss: 0.6445 - sparse_categorical_accuracy: 0.7054
# Epoch 92/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - loss: 0.6378 - sparse_categorical_accuracy: 0.7186
# Epoch 93/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - loss: 0.6095 - sparse_categorical_accuracy: 0.7710
# Epoch 94/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - loss: 0.9902 - sparse_categorical_accuracy: 0.6374
# Epoch 95/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - loss: 0.6466 - sparse_categorical_accuracy: 0.6514
# Epoch 96/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - loss: 1.1031 - sparse_categorical_accuracy: 0.5662
# Epoch 97/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - loss: 0.8764 - sparse_categorical_accuracy: 0.6261
# Epoch 98/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 74ms/step - loss: 1.0763 - sparse_categorical_accuracy: 0.5175
# Epoch 99/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 2s 99ms/step - loss: 0.7130 - sparse_categorical_accuracy: 0.6851
# Epoch 100/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 2s 68ms/step - loss: 0.4954 - sparse_categorical_accuracy: 0.8164
# Zapisano wagi: models/e2_alexnet_rot90.weights.h5
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 286ms/step - loss: 10.1387 - sparse_categorical_accuracy: 0.1719
# === Trenowanie: alexnet | augmentacja: bright | klasy: 5 ===
# Epoch 1/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 8s 300ms/step - loss: 1.6113 - sparse_categorical_accuracy: 0.1966
# Epoch 2/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 4s 68ms/step - loss: 1.6102 - sparse_categorical_accuracy: 0.2177
# Epoch 3/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - loss: 1.6094 - sparse_categorical_accuracy: 0.2076
# Epoch 4/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - loss: 1.6098 - sparse_categorical_accuracy: 0.1853
# Epoch 5/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - loss: 1.6106 - sparse_categorical_accuracy: 0.1949
# Epoch 6/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - loss: 1.6079 - sparse_categorical_accuracy: 0.2112
# Epoch 7/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 2s 98ms/step - loss: 1.6048 - sparse_categorical_accuracy: 0.1891
# Epoch 8/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 82ms/step - loss: 1.6152 - sparse_categorical_accuracy: 0.1732
# Epoch 9/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - loss: 1.6048 - sparse_categorical_accuracy: 0.2478
# Epoch 10/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - loss: 1.6106 - sparse_categorical_accuracy: 0.1747
# Epoch 11/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - loss: 1.6075 - sparse_categorical_accuracy: 0.2311
# Epoch 12/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - loss: 1.6077 - sparse_categorical_accuracy: 0.1955
# Epoch 13/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - loss: 1.6113 - sparse_categorical_accuracy: 0.1885
# Epoch 14/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - loss: 1.6080 - sparse_categorical_accuracy: 0.2290
# Epoch 15/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - loss: 1.5938 - sparse_categorical_accuracy: 0.2937
# Epoch 16/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - loss: 1.5781 - sparse_categorical_accuracy: 0.2765
# Epoch 17/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 82ms/step - loss: 1.6524 - sparse_categorical_accuracy: 0.1330
# Epoch 18/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 2s 68ms/step - loss: 1.6133 - sparse_categorical_accuracy: 0.1767
# Epoch 19/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - loss: 1.6056 - sparse_categorical_accuracy: 0.1694
# Epoch 20/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 69ms/step - loss: 1.5889 - sparse_categorical_accuracy: 0.2331
# Epoch 21/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - loss: 1.5172 - sparse_categorical_accuracy: 0.3505
# Epoch 22/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - loss: 1.5851 - sparse_categorical_accuracy: 0.2144
# Epoch 23/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 69ms/step - loss: 1.5965 - sparse_categorical_accuracy: 0.2477
# Epoch 24/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - loss: 1.6132 - sparse_categorical_accuracy: 0.1852
# Epoch 25/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - loss: 1.5654 - sparse_categorical_accuracy: 0.2759
# Epoch 26/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 83ms/step - loss: 1.5206 - sparse_categorical_accuracy: 0.3649
# Epoch 27/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 2s 67ms/step - loss: 1.5567 - sparse_categorical_accuracy: 0.2912
# Epoch 28/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - loss: 1.6385 - sparse_categorical_accuracy: 0.2130
# Epoch 29/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - loss: 1.6164 - sparse_categorical_accuracy: 0.2260
# Epoch 30/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - loss: 1.6076 - sparse_categorical_accuracy: 0.2177
# Epoch 31/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 69ms/step - loss: 1.6061 - sparse_categorical_accuracy: 0.2375
# Epoch 32/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - loss: 1.5931 - sparse_categorical_accuracy: 0.2635
# Epoch 33/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - loss: 1.5963 - sparse_categorical_accuracy: 0.2512
# Epoch 34/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - loss: 1.5956 - sparse_categorical_accuracy: 0.1672
# Epoch 35/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - loss: 1.6110 - sparse_categorical_accuracy: 0.2393
# Epoch 36/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 2s 98ms/step - loss: 1.6064 - sparse_categorical_accuracy: 0.2640
# Epoch 37/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 2s 67ms/step - loss: 1.6075 - sparse_categorical_accuracy: 0.2292
# Epoch 38/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - loss: 1.6133 - sparse_categorical_accuracy: 0.1514
# Epoch 39/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - loss: 1.6100 - sparse_categorical_accuracy: 0.2067
# Epoch 40/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - loss: 1.6158 - sparse_categorical_accuracy: 0.1642
# Epoch 41/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - loss: 1.6123 - sparse_categorical_accuracy: 0.1734
# Epoch 42/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - loss: 1.6090 - sparse_categorical_accuracy: 0.1772
# Epoch 43/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - loss: 1.6107 - sparse_categorical_accuracy: 0.1697
# Epoch 44/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - loss: 1.5961 - sparse_categorical_accuracy: 0.1978
# Epoch 45/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 2s 98ms/step - loss: 1.6134 - sparse_categorical_accuracy: 0.1780
# Epoch 46/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 80ms/step - loss: 1.6183 - sparse_categorical_accuracy: 0.2000
# Epoch 47/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - loss: 1.6059 - sparse_categorical_accuracy: 0.2599
# Epoch 48/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - loss: 1.6090 - sparse_categorical_accuracy: 0.2149
# Epoch 49/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - loss: 1.6134 - sparse_categorical_accuracy: 0.1592
# Epoch 50/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - loss: 1.6121 - sparse_categorical_accuracy: 0.2128
# Epoch 51/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - loss: 1.6078 - sparse_categorical_accuracy: 0.2195
# Epoch 52/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - loss: 1.6102 - sparse_categorical_accuracy: 0.2019
# Epoch 53/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - loss: 1.6182 - sparse_categorical_accuracy: 0.1364
# Epoch 54/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - loss: 1.6058 - sparse_categorical_accuracy: 0.2159
# Epoch 55/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 70ms/step - loss: 1.6104 - sparse_categorical_accuracy: 0.2233
# Epoch 56/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 2s 101ms/step - loss: 1.6091 - sparse_categorical_accuracy: 0.2137
# Epoch 57/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 76ms/step - loss: 1.6138 - sparse_categorical_accuracy: 0.1337
# Epoch 58/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 64ms/step - loss: 1.6161 - sparse_categorical_accuracy: 0.1220
# Epoch 59/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - loss: 1.6118 - sparse_categorical_accuracy: 0.1913
# Epoch 60/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - loss: 1.6092 - sparse_categorical_accuracy: 0.1904
# Epoch 61/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - loss: 1.6094 - sparse_categorical_accuracy: 0.2036
# Epoch 62/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - loss: 1.6110 - sparse_categorical_accuracy: 0.2051
# Epoch 63/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - loss: 1.6083 - sparse_categorical_accuracy: 0.2356
# Epoch 64/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - loss: 1.6121 - sparse_categorical_accuracy: 0.1383
# Epoch 65/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - loss: 1.6154 - sparse_categorical_accuracy: 0.1725
# Epoch 66/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 81ms/step - loss: 1.6100 - sparse_categorical_accuracy: 0.2130
# Epoch 67/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 2s 96ms/step - loss: 1.6097 - sparse_categorical_accuracy: 0.1852
# Epoch 68/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 2s 65ms/step - loss: 1.6079 - sparse_categorical_accuracy: 0.2360
# Epoch 69/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - loss: 1.6142 - sparse_categorical_accuracy: 0.1141
# Epoch 70/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - loss: 1.6104 - sparse_categorical_accuracy: 0.2229
# Epoch 71/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - loss: 1.6112 - sparse_categorical_accuracy: 0.2653
# Epoch 72/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - loss: 1.6020 - sparse_categorical_accuracy: 0.2561
# Epoch 73/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - loss: 1.6079 - sparse_categorical_accuracy: 0.1736
# Epoch 74/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - loss: 1.6144 - sparse_categorical_accuracy: 0.1896
# Epoch 75/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - loss: 1.6085 - sparse_categorical_accuracy: 0.1806
# Epoch 76/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 81ms/step - loss: 1.6108 - sparse_categorical_accuracy: 0.2063
# Epoch 77/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 91ms/step - loss: 1.6139 - sparse_categorical_accuracy: 0.1704
# Epoch 78/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 72ms/step - loss: 1.6089 - sparse_categorical_accuracy: 0.2093
# Epoch 79/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - loss: 1.6094 - sparse_categorical_accuracy: 0.1915
# Epoch 80/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - loss: 1.6116 - sparse_categorical_accuracy: 0.1878
# Epoch 81/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - loss: 1.6163 - sparse_categorical_accuracy: 0.1965
# Epoch 82/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - loss: 1.6113 - sparse_categorical_accuracy: 0.2154
# Epoch 83/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - loss: 1.6099 - sparse_categorical_accuracy: 0.1464
# Epoch 84/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - loss: 1.6096 - sparse_categorical_accuracy: 0.2364
# Epoch 85/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - loss: 1.6119 - sparse_categorical_accuracy: 0.1681
# Epoch 86/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - loss: 1.6115 - sparse_categorical_accuracy: 0.1628
# Epoch 87/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 2s 85ms/step - loss: 1.6149 - sparse_categorical_accuracy: 0.1856
# Epoch 88/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 88ms/step - loss: 1.6155 - sparse_categorical_accuracy: 0.1890
# Epoch 89/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 2s 65ms/step - loss: 1.6091 - sparse_categorical_accuracy: 0.1754
# Epoch 90/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - loss: 1.6133 - sparse_categorical_accuracy: 0.1127
# Epoch 91/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - loss: 1.6092 - sparse_categorical_accuracy: 0.2149
# Epoch 92/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - loss: 1.6071 - sparse_categorical_accuracy: 0.2164
# Epoch 93/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - loss: 1.6121 - sparse_categorical_accuracy: 0.1572
# Epoch 94/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - loss: 1.6128 - sparse_categorical_accuracy: 0.1390
# Epoch 95/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - loss: 1.6104 - sparse_categorical_accuracy: 0.2418
# Epoch 96/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - loss: 1.6156 - sparse_categorical_accuracy: 0.1534
# Epoch 97/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 2s 91ms/step - loss: 1.6087 - sparse_categorical_accuracy: 0.2123
# Epoch 98/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 89ms/step - loss: 1.6057 - sparse_categorical_accuracy: 0.2280
# Epoch 99/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 2s 66ms/step - loss: 1.6088 - sparse_categorical_accuracy: 0.1770
# Epoch 100/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - loss: 1.6117 - sparse_categorical_accuracy: 0.1537
# Zapisano wagi: models/e2_alexnet_bright.weights.h5
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 278ms/step - loss: 1.6219 - sparse_categorical_accuracy: 0.1625
# === Trenowanie: alexnet | augmentacja: contrast | klasy: 5 ===
# Epoch 1/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 8s 256ms/step - loss: 1.6110 - sparse_categorical_accuracy: 0.1902
# Epoch 2/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 69ms/step - loss: 1.6090 - sparse_categorical_accuracy: 0.2462
# Epoch 3/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - loss: 1.6067 - sparse_categorical_accuracy: 0.2623
# Epoch 4/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - loss: 1.6014 - sparse_categorical_accuracy: 0.1889
# Epoch 5/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 69ms/step - loss: 1.5851 - sparse_categorical_accuracy: 0.2573
# Epoch 6/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - loss: 1.5451 - sparse_categorical_accuracy: 0.3179
# Epoch 7/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 69ms/step - loss: 1.6104 - sparse_categorical_accuracy: 0.1761
# Epoch 8/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 2s 102ms/step - loss: 1.6144 - sparse_categorical_accuracy: 0.1958
# Epoch 9/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 79ms/step - loss: 1.6041 - sparse_categorical_accuracy: 0.2226
# Epoch 10/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 2s 68ms/step - loss: 1.5992 - sparse_categorical_accuracy: 0.3247
# Epoch 11/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - loss: 1.5804 - sparse_categorical_accuracy: 0.3553
# Epoch 12/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - loss: 1.5652 - sparse_categorical_accuracy: 0.2938
# Epoch 13/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 69ms/step - loss: 1.4388 - sparse_categorical_accuracy: 0.4148
# Epoch 14/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - loss: 1.5389 - sparse_categorical_accuracy: 0.2658
# Epoch 15/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - loss: 1.4730 - sparse_categorical_accuracy: 0.3819
# Epoch 16/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 70ms/step - loss: 1.5215 - sparse_categorical_accuracy: 0.3307
# Epoch 17/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 2s 104ms/step - loss: 1.4401 - sparse_categorical_accuracy: 0.3148
# Epoch 18/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 81ms/step - loss: 1.3664 - sparse_categorical_accuracy: 0.4269
# Epoch 19/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 69ms/step - loss: 1.3960 - sparse_categorical_accuracy: 0.3111
# Epoch 20/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - loss: 1.4285 - sparse_categorical_accuracy: 0.3351
# Epoch 21/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 69ms/step - loss: 1.2881 - sparse_categorical_accuracy: 0.4551
# Epoch 22/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 69ms/step - loss: 1.2375 - sparse_categorical_accuracy: 0.3866
# Epoch 23/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 69ms/step - loss: 1.2587 - sparse_categorical_accuracy: 0.3300
# Epoch 24/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 69ms/step - loss: 1.2735 - sparse_categorical_accuracy: 0.4535
# Epoch 25/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - loss: 1.2606 - sparse_categorical_accuracy: 0.4427
# Epoch 26/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 69ms/step - loss: 1.4231 - sparse_categorical_accuracy: 0.3937
# Epoch 27/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 82ms/step - loss: 1.4081 - sparse_categorical_accuracy: 0.3257
# Epoch 28/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 2s 68ms/step - loss: 1.2362 - sparse_categorical_accuracy: 0.3313
# Epoch 29/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - loss: 1.1117 - sparse_categorical_accuracy: 0.4656
# Epoch 30/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - loss: 1.1864 - sparse_categorical_accuracy: 0.5058
# Epoch 31/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - loss: 1.1349 - sparse_categorical_accuracy: 0.5345
# Epoch 32/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 69ms/step - loss: 1.1825 - sparse_categorical_accuracy: 0.3778
# Epoch 33/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - loss: 1.7374 - sparse_categorical_accuracy: 0.2264
# Epoch 34/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - loss: 1.8802 - sparse_categorical_accuracy: 0.1725
# Epoch 35/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 70ms/step - loss: 1.6033 - sparse_categorical_accuracy: 0.2240
# Epoch 36/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 2s 95ms/step - loss: 1.6100 - sparse_categorical_accuracy: 0.2375
# Epoch 37/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 2s 97ms/step - loss: 1.6088 - sparse_categorical_accuracy: 0.2286
# Epoch 38/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - loss: 1.6149 - sparse_categorical_accuracy: 0.1686
# Epoch 39/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - loss: 1.6060 - sparse_categorical_accuracy: 0.2248
# Epoch 40/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - loss: 1.6170 - sparse_categorical_accuracy: 0.1531
# Epoch 41/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - loss: 1.6111 - sparse_categorical_accuracy: 0.1821
# Epoch 42/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - loss: 1.6099 - sparse_categorical_accuracy: 0.1772
# Epoch 43/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - loss: 1.6142 - sparse_categorical_accuracy: 0.1661
# Epoch 44/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - loss: 1.6084 - sparse_categorical_accuracy: 0.1861
# Epoch 45/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - loss: 1.6158 - sparse_categorical_accuracy: 0.2247
# Epoch 46/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 72ms/step - loss: 1.6144 - sparse_categorical_accuracy: 0.2002
# Epoch 47/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 2s 100ms/step - loss: 1.6051 - sparse_categorical_accuracy: 0.2400
# Epoch 48/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 75ms/step - loss: 1.6038 - sparse_categorical_accuracy: 0.2149
# Epoch 49/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - loss: 1.6095 - sparse_categorical_accuracy: 0.1779
# Epoch 50/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - loss: 1.6037 - sparse_categorical_accuracy: 0.2187
# Epoch 51/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - loss: 1.5787 - sparse_categorical_accuracy: 0.3657
# Epoch 52/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - loss: 1.5182 - sparse_categorical_accuracy: 0.2946
# Epoch 53/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - loss: 1.6265 - sparse_categorical_accuracy: 0.2690
# Epoch 54/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - loss: 1.5966 - sparse_categorical_accuracy: 0.2867
# Epoch 55/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - loss: 1.6123 - sparse_categorical_accuracy: 0.2373
# Epoch 56/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - loss: 1.6126 - sparse_categorical_accuracy: 0.2091
# Epoch 57/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 2s 97ms/step - loss: 1.6171 - sparse_categorical_accuracy: 0.1189
# Epoch 58/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 2s 67ms/step - loss: 1.6254 - sparse_categorical_accuracy: 0.0647
# Epoch 59/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - loss: 1.6122 - sparse_categorical_accuracy: 0.1740
# Epoch 60/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - loss: 1.6116 - sparse_categorical_accuracy: 0.1943
# Epoch 61/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - loss: 1.6090 - sparse_categorical_accuracy: 0.2021
# Epoch 62/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - loss: 1.6131 - sparse_categorical_accuracy: 0.1645
# Epoch 63/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - loss: 1.6104 - sparse_categorical_accuracy: 0.1747
# Epoch 64/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - loss: 1.6110 - sparse_categorical_accuracy: 0.2054
# Epoch 65/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - loss: 1.6163 - sparse_categorical_accuracy: 0.1511
# Epoch 66/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 2s 101ms/step - loss: 1.6110 - sparse_categorical_accuracy: 0.2253
# Epoch 67/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 89ms/step - loss: 1.6120 - sparse_categorical_accuracy: 0.2303
# Epoch 68/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - loss: 1.6085 - sparse_categorical_accuracy: 0.2252
# Epoch 69/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - loss: 1.6159 - sparse_categorical_accuracy: 0.1395
# Epoch 70/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - loss: 1.6134 - sparse_categorical_accuracy: 0.2594
# Epoch 71/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - loss: 1.6139 - sparse_categorical_accuracy: 0.2653
# Epoch 72/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - loss: 1.6032 - sparse_categorical_accuracy: 0.2551
# Epoch 73/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - loss: 1.6086 - sparse_categorical_accuracy: 0.2383
# Epoch 74/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - loss: 1.6161 - sparse_categorical_accuracy: 0.1868
# Epoch 75/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - loss: 1.6087 - sparse_categorical_accuracy: 0.2030
# Epoch 76/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 95ms/step - loss: 1.6092 - sparse_categorical_accuracy: 0.2195
# Epoch 77/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 2s 66ms/step - loss: 1.6146 - sparse_categorical_accuracy: 0.1357
# Epoch 78/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - loss: 1.6099 - sparse_categorical_accuracy: 0.1733
# Epoch 79/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - loss: 1.6116 - sparse_categorical_accuracy: 0.1453
# Epoch 80/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - loss: 1.6130 - sparse_categorical_accuracy: 0.1770
# Epoch 81/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - loss: 1.6193 - sparse_categorical_accuracy: 0.1928
# Epoch 82/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - loss: 1.6109 - sparse_categorical_accuracy: 0.2154
# Epoch 83/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - loss: 1.6101 - sparse_categorical_accuracy: 0.1731
# Epoch 84/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - loss: 1.6099 - sparse_categorical_accuracy: 0.2164
# Epoch 85/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 2s 87ms/step - loss: 1.6132 - sparse_categorical_accuracy: 0.1754
# Epoch 86/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 2s 96ms/step - loss: 1.6123 - sparse_categorical_accuracy: 0.1441
# Epoch 87/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 73ms/step - loss: 1.6144 - sparse_categorical_accuracy: 0.2046
# Epoch 88/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - loss: 1.6150 - sparse_categorical_accuracy: 0.1922
# Epoch 89/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 69ms/step - loss: 1.6113 - sparse_categorical_accuracy: 0.1871
# Epoch 90/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - loss: 1.6132 - sparse_categorical_accuracy: 0.1296
# Epoch 91/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - loss: 1.6093 - sparse_categorical_accuracy: 0.2149
# Epoch 92/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - loss: 1.6101 - sparse_categorical_accuracy: 0.2275
# Epoch 93/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - loss: 1.6141 - sparse_categorical_accuracy: 0.1525
# Epoch 94/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - loss: 1.6148 - sparse_categorical_accuracy: 0.1304
# Epoch 95/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 75ms/step - loss: 1.6103 - sparse_categorical_accuracy: 0.1897
# Epoch 96/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 2s 94ms/step - loss: 1.6166 - sparse_categorical_accuracy: 0.1534
# Epoch 97/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 82ms/step - loss: 1.6116 - sparse_categorical_accuracy: 0.2063
# Epoch 98/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - loss: 1.6060 - sparse_categorical_accuracy: 0.2049
# Epoch 99/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - loss: 1.6089 - sparse_categorical_accuracy: 0.1644
# Epoch 100/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - loss: 1.6112 - sparse_categorical_accuracy: 0.2145
# Zapisano wagi: models/e2_alexnet_contrast.weights.h5
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 285ms/step - loss: 1.6212 - sparse_categorical_accuracy: 0.1625
# === Trenowanie: resnet50 | augmentacja: flip | klasy: 5 ===
# Epoch 1/10
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 17s 487ms/step - loss: 1.5470 - sparse_categorical_accuracy: 0.3731
# Epoch 2/10
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 2s 95ms/step - loss: 0.8030 - sparse_categorical_accuracy: 0.7945
# Epoch 3/10
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 2s 97ms/step - loss: 0.6453 - sparse_categorical_accuracy: 0.8052
# Epoch 4/10
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 2s 97ms/step - loss: 0.4505 - sparse_categorical_accuracy: 0.9207
# Epoch 5/10
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 2s 96ms/step - loss: 0.3653 - sparse_categorical_accuracy: 0.9190
# Epoch 6/10
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 2s 96ms/step - loss: 0.3016 - sparse_categorical_accuracy: 0.9300
# Epoch 7/10
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 2s 98ms/step - loss: 0.2619 - sparse_categorical_accuracy: 0.9295
# Epoch 8/10
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 2s 110ms/step - loss: 0.2783 - sparse_categorical_accuracy: 0.9399
# Epoch 9/10
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 2s 97ms/step - loss: 0.1995 - sparse_categorical_accuracy: 0.9561
# Epoch 10/10
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 2s 98ms/step - loss: 0.1963 - sparse_categorical_accuracy: 0.9386
# Zapisano wagi: models/e2_resnet50_flip.weights.h5
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 6s 1s/step - loss: 0.8449 - sparse_categorical_accuracy: 0.5875
# === Trenowanie: resnet50 | augmentacja: rot90 | klasy: 5 ===
# Epoch 1/10
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 16s 359ms/step - loss: 1.6000 - sparse_categorical_accuracy: 0.2562
# Epoch 2/10
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 2s 105ms/step - loss: 0.9464 - sparse_categorical_accuracy: 0.6034
# Epoch 3/10
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 2s 96ms/step - loss: 0.7015 - sparse_categorical_accuracy: 0.7813
# Epoch 4/10
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 2s 97ms/step - loss: 0.5666 - sparse_categorical_accuracy: 0.8510
# Epoch 5/10
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 2s 97ms/step - loss: 0.3583 - sparse_categorical_accuracy: 0.9083
# Epoch 6/10
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 2s 98ms/step - loss: 0.3299 - sparse_categorical_accuracy: 0.9249
# Epoch 7/10
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 2s 99ms/step - loss: 0.3034 - sparse_categorical_accuracy: 0.9455
# Epoch 8/10
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 2s 100ms/step - loss: 0.2622 - sparse_categorical_accuracy: 0.9672
# Epoch 9/10
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 2s 110ms/step - loss: 0.2212 - sparse_categorical_accuracy: 0.9773
# Epoch 10/10
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 2s 101ms/step - loss: 0.2390 - sparse_categorical_accuracy: 0.9495
# Zapisano wagi: models/e2_resnet50_rot90.weights.h5
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 6s 974ms/step - loss: 1.2070 - sparse_categorical_accuracy: 0.2906
# === Trenowanie: resnet50 | augmentacja: bright | klasy: 5 ===
# Epoch 1/10
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 15s 327ms/step - loss: 1.7097 - sparse_categorical_accuracy: 0.1612
# Epoch 2/10
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 2s 96ms/step - loss: 0.8600 - sparse_categorical_accuracy: 0.7297
# Epoch 3/10
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 2s 99ms/step - loss: 0.6478 - sparse_categorical_accuracy: 0.7836
# Epoch 4/10
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 2s 107ms/step - loss: 0.4800 - sparse_categorical_accuracy: 0.8588
# Epoch 5/10
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 2s 97ms/step - loss: 0.3767 - sparse_categorical_accuracy: 0.8743
# Epoch 6/10
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 2s 96ms/step - loss: 0.3074 - sparse_categorical_accuracy: 0.9613
# Epoch 7/10
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 2s 96ms/step - loss: 0.2664 - sparse_categorical_accuracy: 0.9612
# Epoch 8/10
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 2s 97ms/step - loss: 0.2842 - sparse_categorical_accuracy: 0.9312
# Epoch 9/10
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 2s 97ms/step - loss: 0.1878 - sparse_categorical_accuracy: 0.9782
# Epoch 10/10
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 2s 99ms/step - loss: 0.1826 - sparse_categorical_accuracy: 0.9557
# Zapisano wagi: models/e2_resnet50_bright.weights.h5
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 6s 1s/step - loss: 0.8785 - sparse_categorical_accuracy: 0.6687
# === Trenowanie: resnet50 | augmentacja: contrast | klasy: 5 ===
# Epoch 1/10
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 15s 331ms/step - loss: 1.5242 - sparse_categorical_accuracy: 0.4005
# Epoch 2/10
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 3s 98ms/step - loss: 0.8294 - sparse_categorical_accuracy: 0.6892
# Epoch 3/10
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 2s 96ms/step - loss: 0.6009 - sparse_categorical_accuracy: 0.8429
# Epoch 4/10
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 2s 103ms/step - loss: 0.4732 - sparse_categorical_accuracy: 0.8806
# Epoch 5/10
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 2s 110ms/step - loss: 0.3130 - sparse_categorical_accuracy: 0.9211
# Epoch 6/10
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 2s 96ms/step - loss: 0.2927 - sparse_categorical_accuracy: 0.9441
# Epoch 7/10
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 2s 97ms/step - loss: 0.2630 - sparse_categorical_accuracy: 0.9479
# Epoch 8/10
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 2s 99ms/step - loss: 0.2431 - sparse_categorical_accuracy: 0.9365
# Epoch 9/10
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 2s 98ms/step - loss: 0.1949 - sparse_categorical_accuracy: 0.9732
# Epoch 10/10
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 2s 101ms/step - loss: 0.1706 - sparse_categorical_accuracy: 0.9846
# Zapisano wagi: models/e2_resnet50_contrast.weights.h5
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 6s 996ms/step - loss: 0.8490 - sparse_categorical_accuracy: 0.7156
#       model augmentation  epochs  test_acc  test_loss  \
# 2   alexnet       bright     100      0.20   1.610024
# 3   alexnet     contrast     100      0.20   1.610019
# 0   alexnet         flip     100      0.20   1.609844
# 1   alexnet        rot90     100      0.25   9.592699
# 6  resnet50       bright      10      0.65   0.977655
# 7  resnet50     contrast      10      0.65   1.003232
# 4  resnet50         flip      10      0.55   0.958860
# 5  resnet50        rot90      10      0.30   1.161275
#
#                              weights_path
# 2     models/e2_alexnet_bright.weights.h5
# 3   models/e2_alexnet_contrast.weights.h5
# 0       models/e2_alexnet_flip.weights.h5
# 1      models/e2_alexnet_rot90.weights.h5
# 6    models/e2_resnet50_bright.weights.h5
# 7  models/e2_resnet50_contrast.weights.h5
# 4      models/e2_resnet50_flip.weights.h5
# 5     models/e2_resnet50_rot90.weights.h5
