# %% [markdown]
# # Experiment One
# All available training data

# %% [markdown]
# ## Augmentation of dataset

# %%
EXP_NUM=3

# %%
import tensorflow as tf
from pathlib import Path


def augment_in_place_orig_plus_4_no_resize(
    root: str | Path,
    *,
    allowed_ext: tuple[str, ...] = (".jpg", ".jpeg", ".png", ".webp", ".bmp", ".tif", ".tiff"),
    jpeg_quality: int = 95,
    suffix_sep: str = "__",
) -> dict[str, int]:
    """
    Dla każdego obrazu w root/<class_name>/:
      - NIE zmienia wymiarów obrazu
      - NIE usuwa oryginału
      - dodaje 4 nowe obrazy w tym samym folderze:
        flip, rot90, bright, contrast

    Zwraca: dict {class_name: liczba_dodanych_obrazów}
    """
    root = Path(root)
    allowed = {e.lower() for e in allowed_ext}
    stats: dict[str, int] = {}

    def load_image(path: Path) -> tf.Tensor:
        b = tf.io.read_file(str(path))
        # decode_image zachowuje oryginalny rozmiar
        img = tf.image.decode_image(b, channels=3, expand_animations=False)
        img = tf.cast(tf.clip_by_value(img, 0, 255), tf.uint8)
        return img

    def save_jpeg(img_uint8: tf.Tensor, out_path: Path):
        jpeg = tf.io.encode_jpeg(img_uint8, quality=jpeg_quality)
        tf.io.write_file(str(out_path), jpeg)

    # 4 augmentacje zachowujące rozmiar
    def aug_flip(img):      return tf.image.flip_left_right(img)
    def aug_rot90(img):     return tf.image.rot90(img, k=1)   # 90°
    def aug_bright(img):
        x = tf.image.adjust_brightness(tf.cast(img, tf.float32), 0.15 * 255.0)
        return tf.cast(tf.clip_by_value(x, 0, 255), tf.uint8)
    def aug_contrast(img):
        x = tf.image.adjust_contrast(tf.cast(img, tf.float32), 1.2)
        return tf.cast(tf.clip_by_value(x, 0, 255), tf.uint8)

    variants = [
        ("flip", aug_flip),
        ("rot90", aug_rot90),
        ("bright", aug_bright),
        ("contrast", aug_contrast),
    ]

    for class_dir in [p for p in root.iterdir() if p.is_dir()]:
        class_name = class_dir.name

        originals = [
            p for p in class_dir.iterdir()
            if p.is_file()
            and p.suffix.lower() in allowed
            and suffix_sep not in p.stem
        ]

        added = 0
        for p in originals:
            img = load_image(p)

            for tag, fn in variants:
                out_path = class_dir / f"{p.stem}{suffix_sep}{tag}.jpg"
                if out_path.exists():
                    continue
                save_jpeg(fn(img), out_path)
                added += 1

        stats[class_name] = added

    return stats

# %%
stats = augment_in_place_orig_plus_4_no_resize(
    root=f"data/E{EXP_NUM}/train",
)

print(stats)
# Out:
# {'black_morel': 68, 'bitter_bolete': 68, 'curry_milkcap': 68, 'destroying_angel': 68, 'brown_birch_bolete': 68}

# %% [markdown]
# ## Importing datasets

# %%
import tensorflow as tf
from pathlib import Path
import os

TRAIN_DIR = f"data/E{EXP_NUM}/train"
TEST_DIR = "data/test"

IMG_SIZE = (512, 512)
BATCH_SIZE = 8
SEED = 42

# 4 augmentacje (takie same dla AlexNet i ResNet50)
AUG_SUFFIX_SEP = "__"
AUG_TAGS = ["flip", "rot90", "bright", "contrast"]

def _list_augmented_files(root: str | Path, tag: str, allowed_ext=(".jpg",".jpeg",".png",".webp",".bmp",".tif",".tiff")):
    root = Path(root)
    allowed = {e.lower() for e in allowed_ext}
    files, labels = [], []
    class_names = sorted([p.name for p in root.iterdir() if p.is_dir()])
    class_to_idx = {c:i for i,c in enumerate(class_names)}
    for c in class_names:
        class_dir = root / c
        for p in class_dir.iterdir():
            if not p.is_file():
                continue
            if p.suffix.lower() not in allowed:
                continue
            # tylko dane zaugmentowane daną augmentacją (bez oryginałów i bez innych augmentacji)
            if f"{AUG_SUFFIX_SEP}{tag}" not in p.stem:
                continue
            files.append(str(p))
            labels.append(class_to_idx[c])
    return files, labels, class_names

def _decode_and_resize(path, label):
    img = tf.io.read_file(path)
    img = tf.image.decode_image(img, channels=3, expand_animations=False)
    img.set_shape([None, None, 3])
    img = tf.image.resize(img, IMG_SIZE, method="bilinear")
    img = tf.cast(img, tf.float32)
    return img, label

def make_train_ds_for_aug(tag: str, shuffle=True):
    files, labels, class_names = _list_augmented_files(TRAIN_DIR, tag)
    if len(files) == 0:
        raise ValueError(f"Brak plików treningowych dla augmentacji '{tag}'. Upewnij się, że augmentacje zostały wygenerowane w {TRAIN_DIR}.")
    ds = tf.data.Dataset.from_tensor_slices((files, labels))
    if shuffle:
        ds = ds.shuffle(buffer_size=min(len(files), 2048), seed=SEED, reshuffle_each_iteration=True)
    ds = ds.map(_decode_and_resize, num_parallel_calls=tf.data.AUTOTUNE)
    ds = ds.batch(BATCH_SIZE).prefetch(tf.data.AUTOTUNE)
    return ds, class_names

# Test (bez augmentacji)
test_ds = tf.keras.utils.image_dataset_from_directory(
    TEST_DIR,
    image_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    shuffle=False,
    label_mode="int"
).prefetch(tf.data.AUTOTUNE)

print("Ustawienia:")
print(" IMG_SIZE   =", IMG_SIZE)
print(" BATCH_SIZE =", BATCH_SIZE)
print(" AUG_TAGS   =", AUG_TAGS)
# Out:
# Found 20 files belonging to 5 classes.
# Ustawienia:
#  IMG_SIZE   = (512, 512)
#  BATCH_SIZE = 8
#  AUG_TAGS   = ['flip', 'rot90', 'bright', 'contrast']

# %% [markdown]
# ## AlexNet512

# %%
import tensorflow as tf

def lrn(x, depth_radius=2, bias=1.0, alpha=1e-4, beta=0.75):
    return tf.nn.local_response_normalization(
        x, depth_radius=depth_radius, bias=bias, alpha=alpha, beta=beta
    )

def build_alexnet_512(input_shape=(512, 512, 3), num_classes=5, dropout=0.2):
    inputs = tf.keras.Input(shape=input_shape)
    x = tf.keras.layers.Rescaling(1./255)(inputs)

    # Conv1
    x = tf.keras.layers.Conv2D(96, 11, strides=4, padding="valid", activation="relu")(x)
    x = tf.keras.layers.Lambda(lrn)(x)
    x = tf.keras.layers.MaxPooling2D(3, strides=2)(x)

    # Conv2
    x = tf.keras.layers.Conv2D(256, 5, padding="same", activation="relu")(x)
    x = tf.keras.layers.Lambda(lrn)(x)
    x = tf.keras.layers.MaxPooling2D(3, strides=2)(x)

    # Conv3-5
    x = tf.keras.layers.Conv2D(384, 3, padding="same", activation="relu")(x)
    x = tf.keras.layers.Conv2D(384, 3, padding="same", activation="relu")(x)
    x = tf.keras.layers.Conv2D(256, 3, padding="same", activation="relu")(x)
    x = tf.keras.layers.MaxPooling2D(3, strides=2)(x)

    # Zamiast Flatten (żeby 512x512 nie zabiło parametrów)
    x = tf.keras.layers.GlobalAveragePooling2D()(x)

    # FC (AlexNet-like)
    x = tf.keras.layers.Dense(4096, activation="relu")(x)
    x = tf.keras.layers.Dropout(dropout)(x)
    x = tf.keras.layers.Dense(4096, activation="relu")(x)
    x = tf.keras.layers.Dropout(dropout)(x)

    outputs = tf.keras.layers.Dense(num_classes, activation="softmax")(x)
    return tf.keras.Model(inputs, outputs, name="alexnet_512")

# %% [markdown]
# ## Residual Network (ResNet50)

# %%
import tensorflow as tf

def build_resnet50_512(num_classes: int, input_shape=(512, 512, 3), train_base: bool = False):
    inputs = tf.keras.Input(shape=input_shape)

    # ResNet50 oczekuje preprocess_input
    x = tf.keras.applications.resnet50.preprocess_input(inputs)

    base = tf.keras.applications.ResNet50(
        include_top=False,
        weights="imagenet",
        input_tensor=x,
        pooling=None
    )
    base.trainable = train_base  # False = zamrożony backbone

    x = base.output
    x = tf.keras.layers.GlobalAveragePooling2D()(x)
    x = tf.keras.layers.Dropout(0.2)(x)
    outputs = tf.keras.layers.Dense(num_classes, activation="softmax")(x)

    model = tf.keras.Model(inputs, outputs, name="resnet50_512")
    return model

# %% [markdown]
# ## Trening 8 modeli (AlexNet i ResNet50 × 4 augmentacje)
#
# - Uczymy łącznie **8 modeli**: 4×AlexNet512 i 4×ResNet50.
# - Dla obu architektur używamy **tych samych 4 augmentacji**: `flip`, `rot90`, `bright`, `contrast`.
# - **Modele uczą się wyłącznie na danych zaugmentowanych** (oryginały są pomijane w `train_ds`).
# - Zbiór testowy pozostaje bez augmentacji.

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
from pathlib import Path

Path("models").mkdir(parents=True, exist_ok=True)

def train_and_evaluate(model_name: str, aug_tag: str):
    train_ds, class_names = make_train_ds_for_aug(aug_tag, shuffle=True)
    num_classes = len(class_names)

    if model_name == "alexnet":
        model = build_alexnet_512(input_shape=(*IMG_SIZE, 3), num_classes=num_classes, dropout=0.2)
        model.compile(
            optimizer=tf.keras.optimizers.SGD(learning_rate=0.01, momentum=0.9),
            loss=tf.keras.losses.SparseCategoricalCrossentropy(),
            metrics=[tf.keras.metrics.SparseCategoricalAccuracy()],
        )
        epochs = 100
    elif model_name == "resnet50":
        model = build_resnet50_512(num_classes=num_classes, input_shape=(*IMG_SIZE, 3), train_base=False)
        model.compile(
            optimizer=tf.keras.optimizers.Adam(learning_rate=1e-3),
            loss=tf.keras.losses.SparseCategoricalCrossentropy(),
            metrics=[tf.keras.metrics.SparseCategoricalAccuracy()],
        )
        epochs = 10
    else:
        raise ValueError("Nieznany model_name")

    print(f"\n=== Trenowanie: {model_name} | augmentacja: {aug_tag} | klasy: {num_classes} ===")
    history = model.fit(train_ds, epochs=epochs, verbose=1)

    weights_path = f"models/e{EXP_NUM}_{model_name}_{aug_tag}.weights.h5"
    model.save_weights(weights_path)
    print("Zapisano wagi:", weights_path)

    test_loss, test_acc = model.evaluate(test_ds, verbose=1)

    # predykcje + macierz pomyłek
    y_true = np.concatenate([y.numpy() for _, y in test_ds], axis=0)
    y_pred = np.argmax(model.predict(test_ds, verbose=0), axis=1)
    cm = confusion_matrix(y_true, y_pred)

    fig, ax = plt.subplots(figsize=(8, 8))
    disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=class_names)
    disp.plot(ax=ax, cmap="Blues", colorbar=True, xticks_rotation=45)
    plt.title(f"Confusion Matrix | {model_name} | aug={aug_tag}")
    plt.tight_layout()
    plt.show()

    return {
        "model": model_name,
        "augmentation": aug_tag,
        "epochs": epochs,
        "test_loss": float(test_loss),
        "test_acc": float(test_acc),
        "weights_path": weights_path,
        "history": history.history,
        "class_names": class_names,
        "confusion_matrix": cm,
    }

results = []
for aug_tag in AUG_TAGS:
    # 4 modele AlexNet (po 1 na augmentację)
    results.append(train_and_evaluate("alexnet", aug_tag))

for aug_tag in AUG_TAGS:
    # 4 modele ResNet50 (po 1 na augmentację)
    results.append(train_and_evaluate("resnet50", aug_tag))

# Podsumowanie
import pandas as pd
summary = pd.DataFrame([{
    "model": r["model"],
    "augmentation": r["augmentation"],
    "epochs": r["epochs"],
    "test_acc": r["test_acc"],
    "test_loss": r["test_loss"],
    "weights_path": r["weights_path"],
} for r in results]).sort_values(["model", "augmentation"])

summary
# Out:
# === Trenowanie: alexnet | augmentacja: flip | klasy: 5 ===
# Epoch 1/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 11s 657ms/step - loss: 1.6125 - sparse_categorical_accuracy: 0.0731
# Epoch 2/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 69ms/step - loss: 1.6078 - sparse_categorical_accuracy: 0.1912
# Epoch 3/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - loss: 1.6120 - sparse_categorical_accuracy: 0.1655
# Epoch 4/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - loss: 1.6130 - sparse_categorical_accuracy: 0.0777
# Epoch 5/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - loss: 1.6103 - sparse_categorical_accuracy: 0.1937
# Epoch 6/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - loss: 1.6086 - sparse_categorical_accuracy: 0.2830
# Epoch 7/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 69ms/step - loss: 1.6082 - sparse_categorical_accuracy: 0.2755
# Epoch 8/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 69ms/step - loss: 1.6137 - sparse_categorical_accuracy: 0.1678
# Epoch 9/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 72ms/step - loss: 1.6121 - sparse_categorical_accuracy: 0.1977
# Epoch 10/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - loss: 1.6087 - sparse_categorical_accuracy: 0.2106
# Epoch 11/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - loss: 1.6114 - sparse_categorical_accuracy: 0.1659
# Epoch 12/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - loss: 1.6091 - sparse_categorical_accuracy: 0.1781
# Epoch 13/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - loss: 1.6096 - sparse_categorical_accuracy: 0.1635
# Epoch 14/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - loss: 1.6085 - sparse_categorical_accuracy: 0.2014
# Epoch 15/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - loss: 1.6087 - sparse_categorical_accuracy: 0.2590
# Epoch 16/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - loss: 1.6160 - sparse_categorical_accuracy: 0.1045
# Epoch 17/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - loss: 1.6083 - sparse_categorical_accuracy: 0.1649
# Epoch 18/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - loss: 1.6054 - sparse_categorical_accuracy: 0.1915
# Epoch 19/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - loss: 1.6121 - sparse_categorical_accuracy: 0.1646
# Epoch 20/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 69ms/step - loss: 1.6089 - sparse_categorical_accuracy: 0.1424
# Epoch 21/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - loss: 1.6003 - sparse_categorical_accuracy: 0.2199
# Epoch 22/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 69ms/step - loss: 1.6025 - sparse_categorical_accuracy: 0.2776
# Epoch 23/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 72ms/step - loss: 1.5916 - sparse_categorical_accuracy: 0.2673
# Epoch 24/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 72ms/step - loss: 1.5891 - sparse_categorical_accuracy: 0.2320
# Epoch 25/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 69ms/step - loss: 1.6270 - sparse_categorical_accuracy: 0.2200
# Epoch 26/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - loss: 1.6140 - sparse_categorical_accuracy: 0.1748
# Epoch 27/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - loss: 1.6120 - sparse_categorical_accuracy: 0.1684
# Epoch 28/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - loss: 1.6113 - sparse_categorical_accuracy: 0.2066
# Epoch 29/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - loss: 1.6031 - sparse_categorical_accuracy: 0.2726
# Epoch 30/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - loss: 1.6201 - sparse_categorical_accuracy: 0.2285
# Epoch 31/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - loss: 1.6110 - sparse_categorical_accuracy: 0.2054
# Epoch 32/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - loss: 1.6201 - sparse_categorical_accuracy: 0.1896
# Epoch 33/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - loss: 1.6062 - sparse_categorical_accuracy: 0.2604
# Epoch 34/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - loss: 1.6170 - sparse_categorical_accuracy: 0.1772
# Epoch 35/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - loss: 1.6101 - sparse_categorical_accuracy: 0.1693
# Epoch 36/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - loss: 1.6105 - sparse_categorical_accuracy: 0.1867
# Epoch 37/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - loss: 1.6129 - sparse_categorical_accuracy: 0.1621
# Epoch 38/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - loss: 1.6091 - sparse_categorical_accuracy: 0.2359
# Epoch 39/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 70ms/step - loss: 1.6084 - sparse_categorical_accuracy: 0.1892
# Epoch 40/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - loss: 1.6094 - sparse_categorical_accuracy: 0.2327
# Epoch 41/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - loss: 1.6118 - sparse_categorical_accuracy: 0.1652
# Epoch 42/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - loss: 1.6074 - sparse_categorical_accuracy: 0.2001
# Epoch 43/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - loss: 1.6087 - sparse_categorical_accuracy: 0.3097
# Epoch 44/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - loss: 1.6070 - sparse_categorical_accuracy: 0.2272
# Epoch 45/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - loss: 1.6117 - sparse_categorical_accuracy: 0.1483
# Epoch 46/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - loss: 1.6051 - sparse_categorical_accuracy: 0.2800
# Epoch 47/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - loss: 1.6061 - sparse_categorical_accuracy: 0.1921
# Epoch 48/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - loss: 1.6049 - sparse_categorical_accuracy: 0.2227
# Epoch 49/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - loss: 1.6141 - sparse_categorical_accuracy: 0.1144
# Epoch 50/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - loss: 1.6005 - sparse_categorical_accuracy: 0.3046
# Epoch 51/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - loss: 1.5990 - sparse_categorical_accuracy: 0.2496
# Epoch 52/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - loss: 1.6045 - sparse_categorical_accuracy: 0.2175
# Epoch 53/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 70ms/step - loss: 1.5938 - sparse_categorical_accuracy: 0.2424
# Epoch 54/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - loss: 1.6041 - sparse_categorical_accuracy: 0.2500
# Epoch 55/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - loss: 1.6168 - sparse_categorical_accuracy: 0.1880
# Epoch 56/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - loss: 1.6148 - sparse_categorical_accuracy: 0.2052
# Epoch 57/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - loss: 1.6092 - sparse_categorical_accuracy: 0.2282
# Epoch 58/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - loss: 1.6100 - sparse_categorical_accuracy: 0.2226
# Epoch 59/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - loss: 1.6203 - sparse_categorical_accuracy: 0.2055
# Epoch 60/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - loss: 1.6072 - sparse_categorical_accuracy: 0.2016
# Epoch 61/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - loss: 1.6084 - sparse_categorical_accuracy: 0.2135
# Epoch 62/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - loss: 1.6079 - sparse_categorical_accuracy: 0.2404
# Epoch 63/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - loss: 1.6114 - sparse_categorical_accuracy: 0.2090
# Epoch 64/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - loss: 1.6145 - sparse_categorical_accuracy: 0.1074
# Epoch 65/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - loss: 1.6099 - sparse_categorical_accuracy: 0.2578
# Epoch 66/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - loss: 1.6105 - sparse_categorical_accuracy: 0.2349
# Epoch 67/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - loss: 1.6076 - sparse_categorical_accuracy: 0.2573
# Epoch 68/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - loss: 1.6118 - sparse_categorical_accuracy: 0.1920
# Epoch 69/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - loss: 1.6083 - sparse_categorical_accuracy: 0.2420
# Epoch 70/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - loss: 1.6056 - sparse_categorical_accuracy: 0.2388
# Epoch 71/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - loss: 1.6087 - sparse_categorical_accuracy: 0.2268
# Epoch 72/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - loss: 1.6050 - sparse_categorical_accuracy: 0.2784
# Epoch 73/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - loss: 1.6138 - sparse_categorical_accuracy: 0.1878
# Epoch 74/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - loss: 1.6072 - sparse_categorical_accuracy: 0.1927
# Epoch 75/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - loss: 1.6088 - sparse_categorical_accuracy: 0.2265
# Epoch 76/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - loss: 1.6057 - sparse_categorical_accuracy: 0.2041
# Epoch 77/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - loss: 1.6063 - sparse_categorical_accuracy: 0.2412
# Epoch 78/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - loss: 1.6088 - sparse_categorical_accuracy: 0.2303
# Epoch 79/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - loss: 1.6060 - sparse_categorical_accuracy: 0.1159
# Epoch 80/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - loss: 1.6026 - sparse_categorical_accuracy: 0.2121
# Epoch 81/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - loss: 1.5952 - sparse_categorical_accuracy: 0.2581
# Epoch 82/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - loss: 1.6004 - sparse_categorical_accuracy: 0.1915
# Epoch 83/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - loss: 1.5913 - sparse_categorical_accuracy: 0.2467
# Epoch 84/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 69ms/step - loss: 1.5832 - sparse_categorical_accuracy: 0.2710
# Epoch 85/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 69ms/step - loss: 1.5787 - sparse_categorical_accuracy: 0.3759
# Epoch 86/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - loss: 1.6299 - sparse_categorical_accuracy: 0.1487
# Epoch 87/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - loss: 1.6163 - sparse_categorical_accuracy: 0.1128
# Epoch 88/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - loss: 1.6121 - sparse_categorical_accuracy: 0.1766
# Epoch 89/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - loss: 1.6182 - sparse_categorical_accuracy: 0.2010
# Epoch 90/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - loss: 1.6066 - sparse_categorical_accuracy: 0.2150
# Epoch 91/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - loss: 1.6107 - sparse_categorical_accuracy: 0.1549
# Epoch 92/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - loss: 1.6133 - sparse_categorical_accuracy: 0.1591
# Epoch 93/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - loss: 1.6122 - sparse_categorical_accuracy: 0.1614
# Epoch 94/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - loss: 1.6123 - sparse_categorical_accuracy: 0.2179
# Epoch 95/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - loss: 1.6058 - sparse_categorical_accuracy: 0.2200
# Epoch 96/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - loss: 1.6078 - sparse_categorical_accuracy: 0.2188
# Epoch 97/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - loss: 1.5942 - sparse_categorical_accuracy: 0.3022
# Epoch 98/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - loss: 1.5913 - sparse_categorical_accuracy: 0.1949
# Epoch 99/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - loss: 1.6041 - sparse_categorical_accuracy: 0.2356
# Epoch 100/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 70ms/step - loss: 1.5830 - sparse_categorical_accuracy: 0.3931
# Zapisano wagi: models/e3_alexnet_flip.weights.h5
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 283ms/step - loss: 1.5721 - sparse_categorical_accuracy: 0.2656
# === Trenowanie: alexnet | augmentacja: rot90 | klasy: 5 ===
# Epoch 1/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 7s 332ms/step - loss: 1.6130 - sparse_categorical_accuracy: 0.0855
# Epoch 2/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 71ms/step - loss: 1.6087 - sparse_categorical_accuracy: 0.2055
# Epoch 3/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 70ms/step - loss: 1.6121 - sparse_categorical_accuracy: 0.1539
# Epoch 4/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - loss: 1.6134 - sparse_categorical_accuracy: 0.1283
# Epoch 5/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - loss: 1.6102 - sparse_categorical_accuracy: 0.1247
# Epoch 6/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - loss: 1.6085 - sparse_categorical_accuracy: 0.2445
# Epoch 7/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - loss: 1.6083 - sparse_categorical_accuracy: 0.2188
# Epoch 8/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - loss: 1.6133 - sparse_categorical_accuracy: 0.1491
# Epoch 9/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - loss: 1.6109 - sparse_categorical_accuracy: 0.1962
# Epoch 10/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - loss: 1.6087 - sparse_categorical_accuracy: 0.2275
# Epoch 11/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - loss: 1.6098 - sparse_categorical_accuracy: 0.1879
# Epoch 12/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - loss: 1.6100 - sparse_categorical_accuracy: 0.1708
# Epoch 13/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - loss: 1.6097 - sparse_categorical_accuracy: 0.1479
# Epoch 14/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - loss: 1.6090 - sparse_categorical_accuracy: 0.2368
# Epoch 15/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - loss: 1.6095 - sparse_categorical_accuracy: 0.2274
# Epoch 16/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - loss: 1.6163 - sparse_categorical_accuracy: 0.1449
# Epoch 17/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 69ms/step - loss: 1.6079 - sparse_categorical_accuracy: 0.2780
# Epoch 18/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 71ms/step - loss: 1.6026 - sparse_categorical_accuracy: 0.2547
# Epoch 19/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - loss: 1.6096 - sparse_categorical_accuracy: 0.2911
# Epoch 20/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - loss: 1.6066 - sparse_categorical_accuracy: 0.2082
# Epoch 21/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - loss: 1.6060 - sparse_categorical_accuracy: 0.2833
# Epoch 22/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - loss: 1.6059 - sparse_categorical_accuracy: 0.3267
# Epoch 23/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - loss: 1.6064 - sparse_categorical_accuracy: 0.2232
# Epoch 24/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - loss: 1.5959 - sparse_categorical_accuracy: 0.3132
# Epoch 25/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - loss: 1.6106 - sparse_categorical_accuracy: 0.1709
# Epoch 26/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 69ms/step - loss: 1.5913 - sparse_categorical_accuracy: 0.2768
# Epoch 27/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - loss: 1.6079 - sparse_categorical_accuracy: 0.2793
# Epoch 28/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - loss: 1.6055 - sparse_categorical_accuracy: 0.2214
# Epoch 29/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - loss: 1.5941 - sparse_categorical_accuracy: 0.1727
# Epoch 30/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - loss: 1.5916 - sparse_categorical_accuracy: 0.2186
# Epoch 31/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - loss: 1.5512 - sparse_categorical_accuracy: 0.4172
# Epoch 32/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 69ms/step - loss: 1.5886 - sparse_categorical_accuracy: 0.2926
# Epoch 33/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 70ms/step - loss: 1.6073 - sparse_categorical_accuracy: 0.2604
# Epoch 34/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - loss: 1.6287 - sparse_categorical_accuracy: 0.1969
# Epoch 35/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - loss: 1.6125 - sparse_categorical_accuracy: 0.2221
# Epoch 36/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - loss: 1.6114 - sparse_categorical_accuracy: 0.1756
# Epoch 37/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - loss: 1.6162 - sparse_categorical_accuracy: 0.1573
# Epoch 38/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - loss: 1.6094 - sparse_categorical_accuracy: 0.1709
# Epoch 39/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - loss: 1.6087 - sparse_categorical_accuracy: 0.1788
# Epoch 40/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - loss: 1.6012 - sparse_categorical_accuracy: 0.2501
# Epoch 41/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - loss: 1.5867 - sparse_categorical_accuracy: 0.2519
# Epoch 42/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - loss: 1.5645 - sparse_categorical_accuracy: 0.2502
# Epoch 43/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - loss: 1.5850 - sparse_categorical_accuracy: 0.2722
# Epoch 44/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - loss: 1.5459 - sparse_categorical_accuracy: 0.3163
# Epoch 45/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - loss: 1.5626 - sparse_categorical_accuracy: 0.2523
# Epoch 46/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - loss: 1.6117 - sparse_categorical_accuracy: 0.2200
# Epoch 47/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - loss: 1.5599 - sparse_categorical_accuracy: 0.2177
# Epoch 48/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - loss: 1.5475 - sparse_categorical_accuracy: 0.3099
# Epoch 49/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - loss: 1.6095 - sparse_categorical_accuracy: 0.1790
# Epoch 50/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - loss: 1.5759 - sparse_categorical_accuracy: 0.2635
# Epoch 51/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - loss: 1.5450 - sparse_categorical_accuracy: 0.3102
# Epoch 52/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - loss: 1.5764 - sparse_categorical_accuracy: 0.2536
# Epoch 53/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - loss: 1.5258 - sparse_categorical_accuracy: 0.3459
# Epoch 54/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - loss: 1.5543 - sparse_categorical_accuracy: 0.1903
# Epoch 55/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - loss: 1.6472 - sparse_categorical_accuracy: 0.2404
# Epoch 56/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - loss: 1.6209 - sparse_categorical_accuracy: 0.1745
# Epoch 57/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - loss: 1.5686 - sparse_categorical_accuracy: 0.2766
# Epoch 58/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - loss: 1.5683 - sparse_categorical_accuracy: 0.2778
# Epoch 59/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - loss: 1.5429 - sparse_categorical_accuracy: 0.3378
# Epoch 60/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - loss: 1.5477 - sparse_categorical_accuracy: 0.2580
# Epoch 61/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - loss: 1.5074 - sparse_categorical_accuracy: 0.3307
# Epoch 62/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - loss: 1.5276 - sparse_categorical_accuracy: 0.2436
# Epoch 63/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 64ms/step - loss: 1.6332 - sparse_categorical_accuracy: 0.1581
# Epoch 64/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - loss: 1.5804 - sparse_categorical_accuracy: 0.1926
# Epoch 65/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 64ms/step - loss: 1.5006 - sparse_categorical_accuracy: 0.2953
# Epoch 66/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - loss: 1.6434 - sparse_categorical_accuracy: 0.2024
# Epoch 67/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - loss: 1.6085 - sparse_categorical_accuracy: 0.2034
# Epoch 68/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 64ms/step - loss: 1.6230 - sparse_categorical_accuracy: 0.1783
# Epoch 69/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 64ms/step - loss: 1.6234 - sparse_categorical_accuracy: 0.1316
# Epoch 70/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - loss: 1.6041 - sparse_categorical_accuracy: 0.1912
# Epoch 71/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 64ms/step - loss: 1.5434 - sparse_categorical_accuracy: 0.2661
# Epoch 72/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - loss: 1.5266 - sparse_categorical_accuracy: 0.3303
# Epoch 73/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - loss: 1.6349 - sparse_categorical_accuracy: 0.2308
# Epoch 74/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - loss: 1.5636 - sparse_categorical_accuracy: 0.3316
# Epoch 75/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - loss: 1.5251 - sparse_categorical_accuracy: 0.3510
# Epoch 76/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - loss: 1.5507 - sparse_categorical_accuracy: 0.2814
# Epoch 77/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 64ms/step - loss: 1.5163 - sparse_categorical_accuracy: 0.3153
# Epoch 78/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - loss: 1.5227 - sparse_categorical_accuracy: 0.3299
# Epoch 79/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - loss: 1.4844 - sparse_categorical_accuracy: 0.3739
# Epoch 80/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - loss: 1.4941 - sparse_categorical_accuracy: 0.3516
# Epoch 81/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - loss: 1.5004 - sparse_categorical_accuracy: 0.2793
# Epoch 82/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - loss: 1.4832 - sparse_categorical_accuracy: 0.2450
# Epoch 83/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - loss: 1.5316 - sparse_categorical_accuracy: 0.2842
# Epoch 84/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - loss: 1.5180 - sparse_categorical_accuracy: 0.3236
# Epoch 85/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - loss: 1.4507 - sparse_categorical_accuracy: 0.3332
# Epoch 86/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - loss: 1.4855 - sparse_categorical_accuracy: 0.3462
# Epoch 87/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - loss: 1.4931 - sparse_categorical_accuracy: 0.4104
# Epoch 88/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - loss: 1.4540 - sparse_categorical_accuracy: 0.3891
# Epoch 89/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - loss: 1.4992 - sparse_categorical_accuracy: 0.3346
# Epoch 90/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - loss: 1.4452 - sparse_categorical_accuracy: 0.3125
# Epoch 91/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - loss: 1.4989 - sparse_categorical_accuracy: 0.2477
# Epoch 92/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - loss: 1.6823 - sparse_categorical_accuracy: 0.2511
# Epoch 93/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - loss: 1.5362 - sparse_categorical_accuracy: 0.3239
# Epoch 94/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - loss: 1.6097 - sparse_categorical_accuracy: 0.1645
# Epoch 95/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - loss: 1.5752 - sparse_categorical_accuracy: 0.2973
# Epoch 96/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - loss: 1.5045 - sparse_categorical_accuracy: 0.2274
# Epoch 97/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - loss: 1.6023 - sparse_categorical_accuracy: 0.1891
# Epoch 98/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - loss: 1.4931 - sparse_categorical_accuracy: 0.3561
# Epoch 99/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - loss: 1.5470 - sparse_categorical_accuracy: 0.2750
# Epoch 100/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - loss: 1.5420 - sparse_categorical_accuracy: 0.2398
# Zapisano wagi: models/e3_alexnet_rot90.weights.h5
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 274ms/step - loss: 1.5346 - sparse_categorical_accuracy: 0.3375
# === Trenowanie: alexnet | augmentacja: bright | klasy: 5 ===
# Epoch 1/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 8s 344ms/step - loss: 1.6110 - sparse_categorical_accuracy: 0.1915
# Epoch 2/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - loss: 1.6089 - sparse_categorical_accuracy: 0.1403
# Epoch 3/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - loss: 1.6135 - sparse_categorical_accuracy: 0.1046
# Epoch 4/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - loss: 1.6125 - sparse_categorical_accuracy: 0.1186
# Epoch 5/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - loss: 1.6112 - sparse_categorical_accuracy: 0.1132
# Epoch 6/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - loss: 1.6091 - sparse_categorical_accuracy: 0.2337
# Epoch 7/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 69ms/step - loss: 1.6091 - sparse_categorical_accuracy: 0.2279
# Epoch 8/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 69ms/step - loss: 1.6121 - sparse_categorical_accuracy: 0.1599
# Epoch 9/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - loss: 1.6116 - sparse_categorical_accuracy: 0.1536
# Epoch 10/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - loss: 1.6084 - sparse_categorical_accuracy: 0.2106
# Epoch 11/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - loss: 1.6094 - sparse_categorical_accuracy: 0.2268
# Epoch 12/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - loss: 1.6096 - sparse_categorical_accuracy: 0.1679
# Epoch 13/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - loss: 1.6101 - sparse_categorical_accuracy: 0.2109
# Epoch 14/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - loss: 1.6087 - sparse_categorical_accuracy: 0.2122
# Epoch 15/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - loss: 1.6084 - sparse_categorical_accuracy: 0.2336
# Epoch 16/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - loss: 1.6171 - sparse_categorical_accuracy: 0.1015
# Epoch 17/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - loss: 1.6092 - sparse_categorical_accuracy: 0.1890
# Epoch 18/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - loss: 1.6060 - sparse_categorical_accuracy: 0.2311
# Epoch 19/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - loss: 1.6113 - sparse_categorical_accuracy: 0.1929
# Epoch 20/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - loss: 1.6068 - sparse_categorical_accuracy: 0.2597
# Epoch 21/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - loss: 1.6074 - sparse_categorical_accuracy: 0.2871
# Epoch 22/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - loss: 1.6065 - sparse_categorical_accuracy: 0.1677
# Epoch 23/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 69ms/step - loss: 1.6099 - sparse_categorical_accuracy: 0.1914
# Epoch 24/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 71ms/step - loss: 1.6040 - sparse_categorical_accuracy: 0.2103
# Epoch 25/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 69ms/step - loss: 1.6148 - sparse_categorical_accuracy: 0.2066
# Epoch 26/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - loss: 1.6068 - sparse_categorical_accuracy: 0.2967
# Epoch 27/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - loss: 1.6093 - sparse_categorical_accuracy: 0.2679
# Epoch 28/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - loss: 1.6074 - sparse_categorical_accuracy: 0.2313
# Epoch 29/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - loss: 1.6083 - sparse_categorical_accuracy: 0.2379
# Epoch 30/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - loss: 1.6153 - sparse_categorical_accuracy: 0.1516
# Epoch 31/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - loss: 1.6065 - sparse_categorical_accuracy: 0.1838
# Epoch 32/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - loss: 1.6054 - sparse_categorical_accuracy: 0.1785
# Epoch 33/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - loss: 1.6112 - sparse_categorical_accuracy: 0.1502
# Epoch 34/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - loss: 1.6104 - sparse_categorical_accuracy: 0.2284
# Epoch 35/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - loss: 1.6062 - sparse_categorical_accuracy: 0.2429
# Epoch 36/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - loss: 1.6025 - sparse_categorical_accuracy: 0.2258
# Epoch 37/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - loss: 1.5932 - sparse_categorical_accuracy: 0.3120
# Epoch 38/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - loss: 1.6067 - sparse_categorical_accuracy: 0.1841
# Epoch 39/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 69ms/step - loss: 1.6004 - sparse_categorical_accuracy: 0.1564
# Epoch 40/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 71ms/step - loss: 1.5783 - sparse_categorical_accuracy: 0.3007
# Epoch 41/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 70ms/step - loss: 1.5471 - sparse_categorical_accuracy: 0.2978
# Epoch 42/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - loss: 1.7641 - sparse_categorical_accuracy: 0.2955
# Epoch 43/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - loss: 1.6559 - sparse_categorical_accuracy: 0.2101
# Epoch 44/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - loss: 1.6125 - sparse_categorical_accuracy: 0.2336
# Epoch 45/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - loss: 1.6311 - sparse_categorical_accuracy: 0.1826
# Epoch 46/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - loss: 1.6226 - sparse_categorical_accuracy: 0.1823
# Epoch 47/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - loss: 1.6190 - sparse_categorical_accuracy: 0.2606
# Epoch 48/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - loss: 1.6110 - sparse_categorical_accuracy: 0.2157
# Epoch 49/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - loss: 1.6163 - sparse_categorical_accuracy: 0.1719
# Epoch 50/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - loss: 1.6124 - sparse_categorical_accuracy: 0.2479
# Epoch 51/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - loss: 1.6114 - sparse_categorical_accuracy: 0.2272
# Epoch 52/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - loss: 1.6146 - sparse_categorical_accuracy: 0.1709
# Epoch 53/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - loss: 1.6118 - sparse_categorical_accuracy: 0.2007
# Epoch 54/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 69ms/step - loss: 1.6098 - sparse_categorical_accuracy: 0.1671
# Epoch 55/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - loss: 1.6149 - sparse_categorical_accuracy: 0.1053
# Epoch 56/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 64ms/step - loss: 1.6097 - sparse_categorical_accuracy: 0.1822
# Epoch 57/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - loss: 1.6101 - sparse_categorical_accuracy: 0.1764
# Epoch 58/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - loss: 1.6124 - sparse_categorical_accuracy: 0.1766
# Epoch 59/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - loss: 1.6158 - sparse_categorical_accuracy: 0.0846
# Epoch 60/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - loss: 1.6074 - sparse_categorical_accuracy: 0.1923
# Epoch 61/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - loss: 1.6069 - sparse_categorical_accuracy: 0.3330
# Epoch 62/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - loss: 1.6063 - sparse_categorical_accuracy: 0.2496
# Epoch 63/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - loss: 1.6105 - sparse_categorical_accuracy: 0.2090
# Epoch 64/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - loss: 1.6137 - sparse_categorical_accuracy: 0.1225
# Epoch 65/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - loss: 1.6099 - sparse_categorical_accuracy: 0.1470
# Epoch 66/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - loss: 1.6106 - sparse_categorical_accuracy: 0.2024
# Epoch 67/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 64ms/step - loss: 1.6076 - sparse_categorical_accuracy: 0.2140
# Epoch 68/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - loss: 1.6121 - sparse_categorical_accuracy: 0.1031
# Epoch 69/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - loss: 1.6082 - sparse_categorical_accuracy: 0.2031
# Epoch 70/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - loss: 1.6079 - sparse_categorical_accuracy: 0.2556
# Epoch 71/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - loss: 1.6103 - sparse_categorical_accuracy: 0.2124
# Epoch 72/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 64ms/step - loss: 1.6080 - sparse_categorical_accuracy: 0.2784
# Epoch 73/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - loss: 1.6128 - sparse_categorical_accuracy: 0.1112
# Epoch 74/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - loss: 1.6119 - sparse_categorical_accuracy: 0.2284
# Epoch 75/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - loss: 1.6090 - sparse_categorical_accuracy: 0.2265
# Epoch 76/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - loss: 1.6084 - sparse_categorical_accuracy: 0.2534
# Epoch 77/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - loss: 1.6088 - sparse_categorical_accuracy: 0.2431
# Epoch 78/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 64ms/step - loss: 1.6130 - sparse_categorical_accuracy: 0.2168
# Epoch 79/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 64ms/step - loss: 1.6138 - sparse_categorical_accuracy: 0.1581
# Epoch 80/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - loss: 1.6085 - sparse_categorical_accuracy: 0.2140
# Epoch 81/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - loss: 1.6069 - sparse_categorical_accuracy: 0.1685
# Epoch 82/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - loss: 1.6055 - sparse_categorical_accuracy: 0.1907
# Epoch 83/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 64ms/step - loss: 1.6067 - sparse_categorical_accuracy: 0.1967
# Epoch 84/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - loss: 1.6194 - sparse_categorical_accuracy: 0.2039
# Epoch 85/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - loss: 1.6107 - sparse_categorical_accuracy: 0.2289
# Epoch 86/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 71ms/step - loss: 1.6109 - sparse_categorical_accuracy: 0.1582
# Epoch 87/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - loss: 1.6141 - sparse_categorical_accuracy: 0.1895
# Epoch 88/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - loss: 1.6082 - sparse_categorical_accuracy: 0.1921
# Epoch 89/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - loss: 1.6093 - sparse_categorical_accuracy: 0.2205
# Epoch 90/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 64ms/step - loss: 1.6103 - sparse_categorical_accuracy: 0.2163
# Epoch 91/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - loss: 1.6105 - sparse_categorical_accuracy: 0.1710
# Epoch 92/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 64ms/step - loss: 1.6147 - sparse_categorical_accuracy: 0.1952
# Epoch 93/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - loss: 1.6038 - sparse_categorical_accuracy: 0.2773
# Epoch 94/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 64ms/step - loss: 1.6055 - sparse_categorical_accuracy: 0.2356
# Epoch 95/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - loss: 1.5990 - sparse_categorical_accuracy: 0.1944
# Epoch 96/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - loss: 1.5904 - sparse_categorical_accuracy: 0.2911
# Epoch 97/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 64ms/step - loss: 1.5832 - sparse_categorical_accuracy: 0.3687
# Epoch 98/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - loss: 1.5934 - sparse_categorical_accuracy: 0.2060
# Epoch 99/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - loss: 1.6184 - sparse_categorical_accuracy: 0.2114
# Epoch 100/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - loss: 1.6236 - sparse_categorical_accuracy: 0.2239
# Zapisano wagi: models/e3_alexnet_bright.weights.h5
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 286ms/step - loss: 1.5897 - sparse_categorical_accuracy: 0.2875
# === Trenowanie: alexnet | augmentacja: contrast | klasy: 5 ===
# Epoch 1/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 7s 333ms/step - loss: 1.6092 - sparse_categorical_accuracy: 0.2287
# Epoch 2/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 72ms/step - loss: 1.6086 - sparse_categorical_accuracy: 0.1972
# Epoch 3/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 69ms/step - loss: 1.6117 - sparse_categorical_accuracy: 0.1435
# Epoch 4/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 71ms/step - loss: 1.6131 - sparse_categorical_accuracy: 0.1000
# Epoch 5/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - loss: 1.6097 - sparse_categorical_accuracy: 0.1300
# Epoch 6/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - loss: 1.6080 - sparse_categorical_accuracy: 0.2337
# Epoch 7/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - loss: 1.6069 - sparse_categorical_accuracy: 0.2794
# Epoch 8/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - loss: 1.6127 - sparse_categorical_accuracy: 0.1852
# Epoch 9/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - loss: 1.6105 - sparse_categorical_accuracy: 0.2134
# Epoch 10/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - loss: 1.6071 - sparse_categorical_accuracy: 0.2275
# Epoch 11/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - loss: 1.6068 - sparse_categorical_accuracy: 0.2256
# Epoch 12/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - loss: 1.6076 - sparse_categorical_accuracy: 0.1952
# Epoch 13/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - loss: 1.6072 - sparse_categorical_accuracy: 0.2349
# Epoch 14/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - loss: 1.6091 - sparse_categorical_accuracy: 0.2256
# Epoch 15/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - loss: 1.6021 - sparse_categorical_accuracy: 0.2540
# Epoch 16/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - loss: 1.6116 - sparse_categorical_accuracy: 0.1101
# Epoch 17/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - loss: 1.5999 - sparse_categorical_accuracy: 0.2400
# Epoch 18/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 69ms/step - loss: 1.6142 - sparse_categorical_accuracy: 0.2163
# Epoch 19/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 72ms/step - loss: 1.5971 - sparse_categorical_accuracy: 0.2616
# Epoch 20/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 69ms/step - loss: 1.5978 - sparse_categorical_accuracy: 0.1412
# Epoch 21/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - loss: 1.6141 - sparse_categorical_accuracy: 0.2465
# Epoch 22/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - loss: 1.5728 - sparse_categorical_accuracy: 0.3657
# Epoch 23/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - loss: 1.5842 - sparse_categorical_accuracy: 0.2649
# Epoch 24/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - loss: 1.6055 - sparse_categorical_accuracy: 0.1999
# Epoch 25/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - loss: 1.8052 - sparse_categorical_accuracy: 0.3526
# Epoch 26/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - loss: 1.6283 - sparse_categorical_accuracy: 0.2027
# Epoch 27/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - loss: 1.6199 - sparse_categorical_accuracy: 0.1117
# Epoch 28/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - loss: 1.6227 - sparse_categorical_accuracy: 0.1870
# Epoch 29/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - loss: 1.6064 - sparse_categorical_accuracy: 0.2158
# Epoch 30/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - loss: 1.6139 - sparse_categorical_accuracy: 0.1291
# Epoch 31/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - loss: 1.6084 - sparse_categorical_accuracy: 0.2383
# Epoch 32/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - loss: 1.6105 - sparse_categorical_accuracy: 0.1525
# Epoch 33/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - loss: 1.6102 - sparse_categorical_accuracy: 0.2604
# Epoch 34/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 71ms/step - loss: 1.6085 - sparse_categorical_accuracy: 0.1748
# Epoch 35/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - loss: 1.6087 - sparse_categorical_accuracy: 0.1771
# Epoch 36/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - loss: 1.6070 - sparse_categorical_accuracy: 0.1867
# Epoch 37/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - loss: 1.6105 - sparse_categorical_accuracy: 0.1884
# Epoch 38/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - loss: 1.6024 - sparse_categorical_accuracy: 0.3769
# Epoch 39/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - loss: 1.6002 - sparse_categorical_accuracy: 0.2224
# Epoch 40/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - loss: 1.5970 - sparse_categorical_accuracy: 0.3488
# Epoch 41/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - loss: 1.5972 - sparse_categorical_accuracy: 0.2748
# Epoch 42/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - loss: 1.5841 - sparse_categorical_accuracy: 0.3498
# Epoch 43/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - loss: 1.5725 - sparse_categorical_accuracy: 0.2709
# Epoch 44/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - loss: 1.5527 - sparse_categorical_accuracy: 0.3579
# Epoch 45/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - loss: 1.4855 - sparse_categorical_accuracy: 0.3933
# Epoch 46/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - loss: 1.5495 - sparse_categorical_accuracy: 0.2767
# Epoch 47/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - loss: 1.6080 - sparse_categorical_accuracy: 0.2189
# Epoch 48/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - loss: 1.5536 - sparse_categorical_accuracy: 0.2953
# Epoch 49/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 69ms/step - loss: 1.5593 - sparse_categorical_accuracy: 0.2739
# Epoch 50/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - loss: 1.5584 - sparse_categorical_accuracy: 0.2564
# Epoch 51/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - loss: 1.5285 - sparse_categorical_accuracy: 0.2964
# Epoch 52/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - loss: 1.5666 - sparse_categorical_accuracy: 0.2722
# Epoch 53/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - loss: 1.4894 - sparse_categorical_accuracy: 0.3111
# Epoch 54/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - loss: 1.5146 - sparse_categorical_accuracy: 0.3770
# Epoch 55/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - loss: 1.6871 - sparse_categorical_accuracy: 0.2432
# Epoch 56/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - loss: 1.5363 - sparse_categorical_accuracy: 0.3526
# Epoch 57/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - loss: 1.4822 - sparse_categorical_accuracy: 0.2711
# Epoch 58/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - loss: 1.4930 - sparse_categorical_accuracy: 0.3008
# Epoch 59/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - loss: 1.5091 - sparse_categorical_accuracy: 0.3682
# Epoch 60/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - loss: 1.4551 - sparse_categorical_accuracy: 0.3315
# Epoch 61/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 69ms/step - loss: 1.4473 - sparse_categorical_accuracy: 0.2937
# Epoch 62/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - loss: 1.4648 - sparse_categorical_accuracy: 0.3596
# Epoch 63/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - loss: 1.5294 - sparse_categorical_accuracy: 0.2246
# Epoch 64/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - loss: 1.5302 - sparse_categorical_accuracy: 0.2593
# Epoch 65/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - loss: 1.5434 - sparse_categorical_accuracy: 0.2311
# Epoch 66/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - loss: 1.6547 - sparse_categorical_accuracy: 0.2165
# Epoch 67/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - loss: 1.5675 - sparse_categorical_accuracy: 0.2893
# Epoch 68/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - loss: 1.5457 - sparse_categorical_accuracy: 0.3593
# Epoch 69/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - loss: 1.5203 - sparse_categorical_accuracy: 0.3433
# Epoch 70/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - loss: 1.4636 - sparse_categorical_accuracy: 0.4340
# Epoch 71/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - loss: 1.5005 - sparse_categorical_accuracy: 0.3012
# Epoch 72/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - loss: 1.4752 - sparse_categorical_accuracy: 0.3514
# Epoch 73/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 69ms/step - loss: 1.5094 - sparse_categorical_accuracy: 0.3614
# Epoch 74/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 69ms/step - loss: 1.4424 - sparse_categorical_accuracy: 0.3576
# Epoch 75/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - loss: 1.4607 - sparse_categorical_accuracy: 0.4430
# Epoch 76/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - loss: 1.5060 - sparse_categorical_accuracy: 0.2169
# Epoch 77/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - loss: 1.4617 - sparse_categorical_accuracy: 0.2674
# Epoch 78/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - loss: 1.4303 - sparse_categorical_accuracy: 0.3753
# Epoch 79/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - loss: 1.4378 - sparse_categorical_accuracy: 0.3433
# Epoch 80/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - loss: 1.3007 - sparse_categorical_accuracy: 0.3963
# Epoch 81/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - loss: 1.3291 - sparse_categorical_accuracy: 0.5351
# Epoch 82/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - loss: 1.4203 - sparse_categorical_accuracy: 0.3563
# Epoch 83/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - loss: 1.3163 - sparse_categorical_accuracy: 0.4072
# Epoch 84/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - loss: 1.2605 - sparse_categorical_accuracy: 0.4484
# Epoch 85/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - loss: 1.3361 - sparse_categorical_accuracy: 0.3697
# Epoch 86/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - loss: 1.3761 - sparse_categorical_accuracy: 0.3424
# Epoch 87/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - loss: 1.3453 - sparse_categorical_accuracy: 0.3760
# Epoch 88/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 69ms/step - loss: 1.3012 - sparse_categorical_accuracy: 0.4323
# Epoch 89/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - loss: 1.3636 - sparse_categorical_accuracy: 0.3538
# Epoch 90/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - loss: 1.4167 - sparse_categorical_accuracy: 0.3623
# Epoch 91/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - loss: 1.5193 - sparse_categorical_accuracy: 0.2704
# Epoch 92/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - loss: 1.5460 - sparse_categorical_accuracy: 0.2966
# Epoch 93/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - loss: 1.4691 - sparse_categorical_accuracy: 0.3208
# Epoch 94/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - loss: 1.2463 - sparse_categorical_accuracy: 0.4528
# Epoch 95/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - loss: 1.4316 - sparse_categorical_accuracy: 0.3262
# Epoch 96/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - loss: 1.4188 - sparse_categorical_accuracy: 0.4361
# Epoch 97/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - loss: 1.4856 - sparse_categorical_accuracy: 0.4367
# Epoch 98/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - loss: 1.4143 - sparse_categorical_accuracy: 0.3489
# Epoch 99/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - loss: 1.3984 - sparse_categorical_accuracy: 0.3637
# Epoch 100/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - loss: 1.3390 - sparse_categorical_accuracy: 0.4078
# Zapisano wagi: models/e3_alexnet_contrast.weights.h5
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 418ms/step - loss: 1.5291 - sparse_categorical_accuracy: 0.3094
# === Trenowanie: resnet50 | augmentacja: flip | klasy: 5 ===
# Epoch 1/10
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 17s 699ms/step - loss: 1.7699 - sparse_categorical_accuracy: 0.2405
# Epoch 2/10
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 95ms/step - loss: 0.9861 - sparse_categorical_accuracy: 0.6256
# Epoch 3/10
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 98ms/step - loss: 0.7497 - sparse_categorical_accuracy: 0.7742
# Epoch 4/10
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 102ms/step - loss: 0.4875 - sparse_categorical_accuracy: 0.7979
# Epoch 5/10
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 99ms/step - loss: 0.3753 - sparse_categorical_accuracy: 0.9526
# Epoch 6/10
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 97ms/step - loss: 0.3007 - sparse_categorical_accuracy: 0.9522
# Epoch 7/10
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 96ms/step - loss: 0.2591 - sparse_categorical_accuracy: 0.9455
# Epoch 8/10
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 96ms/step - loss: 0.2147 - sparse_categorical_accuracy: 0.9682
# Epoch 9/10
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 97ms/step - loss: 0.1910 - sparse_categorical_accuracy: 0.9958
# Epoch 10/10
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 97ms/step - loss: 0.1595 - sparse_categorical_accuracy: 0.9844
# Zapisano wagi: models/e3_resnet50_flip.weights.h5
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 7s 1s/step - loss: 0.4451 - sparse_categorical_accuracy: 0.8625
# === Trenowanie: resnet50 | augmentacja: rot90 | klasy: 5 ===
# Epoch 1/10
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 15s 500ms/step - loss: 1.7778 - sparse_categorical_accuracy: 0.2178
# Epoch 2/10
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 98ms/step - loss: 0.9582 - sparse_categorical_accuracy: 0.7474
# Epoch 3/10
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 98ms/step - loss: 0.6691 - sparse_categorical_accuracy: 0.7829
# Epoch 4/10
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 100ms/step - loss: 0.4540 - sparse_categorical_accuracy: 0.9066
# Epoch 5/10
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 99ms/step - loss: 0.3395 - sparse_categorical_accuracy: 0.9614
# Epoch 6/10
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 98ms/step - loss: 0.3166 - sparse_categorical_accuracy: 0.9698
# Epoch 7/10
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 98ms/step - loss: 0.2616 - sparse_categorical_accuracy: 0.9628
# Epoch 8/10
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 99ms/step - loss: 0.2338 - sparse_categorical_accuracy: 0.9759
# Epoch 9/10
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 100ms/step - loss: 0.2021 - sparse_categorical_accuracy: 0.9682
# Epoch 10/10
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 103ms/step - loss: 0.1324 - sparse_categorical_accuracy: 0.9866
# Zapisano wagi: models/e3_resnet50_rot90.weights.h5
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 6s 998ms/step - loss: 0.6349 - sparse_categorical_accuracy: 0.8219
# === Trenowanie: resnet50 | augmentacja: bright | klasy: 5 ===
# Epoch 1/10
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 14s 414ms/step - loss: 1.7484 - sparse_categorical_accuracy: 0.3051
# Epoch 2/10
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 97ms/step - loss: 0.9834 - sparse_categorical_accuracy: 0.6255
# Epoch 3/10
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 94ms/step - loss: 0.6988 - sparse_categorical_accuracy: 0.8129
# Epoch 4/10
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 94ms/step - loss: 0.4507 - sparse_categorical_accuracy: 0.9463
# Epoch 5/10
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 95ms/step - loss: 0.3586 - sparse_categorical_accuracy: 0.9400
# Epoch 6/10
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 100ms/step - loss: 0.2610 - sparse_categorical_accuracy: 0.9673
# Epoch 7/10
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 103ms/step - loss: 0.2584 - sparse_categorical_accuracy: 0.9779
# Epoch 8/10
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 96ms/step - loss: 0.1870 - sparse_categorical_accuracy: 0.9507
# Epoch 9/10
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 95ms/step - loss: 0.1549 - sparse_categorical_accuracy: 1.0000
# Epoch 10/10
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 96ms/step - loss: 0.1688 - sparse_categorical_accuracy: 0.9759
# Zapisano wagi: models/e3_resnet50_bright.weights.h5
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 6s 1s/step - loss: 0.3496 - sparse_categorical_accuracy: 0.9750
# === Trenowanie: resnet50 | augmentacja: contrast | klasy: 5 ===
# Epoch 1/10
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 14s 411ms/step - loss: 1.7127 - sparse_categorical_accuracy: 0.2957
# Epoch 2/10
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 98ms/step - loss: 0.9800 - sparse_categorical_accuracy: 0.6894
# Epoch 3/10
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 100ms/step - loss: 0.7256 - sparse_categorical_accuracy: 0.7127
# Epoch 4/10
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 103ms/step - loss: 0.4597 - sparse_categorical_accuracy: 0.9251
# Epoch 5/10
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 98ms/step - loss: 0.3943 - sparse_categorical_accuracy: 0.8996
# Epoch 6/10
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 98ms/step - loss: 0.3090 - sparse_categorical_accuracy: 0.9779
# Epoch 7/10
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 97ms/step - loss: 0.2364 - sparse_categorical_accuracy: 0.9861
# Epoch 8/10
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 97ms/step - loss: 0.1834 - sparse_categorical_accuracy: 0.9866
# Epoch 9/10
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 97ms/step - loss: 0.1755 - sparse_categorical_accuracy: 0.9526
# Epoch 10/10
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 100ms/step - loss: 0.1344 - sparse_categorical_accuracy: 1.0000
# Zapisano wagi: models/e3_resnet50_contrast.weights.h5
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 6s 1s/step - loss: 0.4494 - sparse_categorical_accuracy: 0.8313
#       model augmentation  epochs  test_acc  test_loss  \
# 2   alexnet       bright     100      0.20   1.609329
# 3   alexnet     contrast     100      0.40   1.423196
# 0   alexnet         flip     100      0.25   1.571248
# 1   alexnet        rot90     100      0.30   1.545213
# 6  resnet50       bright      10      0.95   0.370874
# 7  resnet50     contrast      10      0.85   0.542793
# 4  resnet50         flip      10      0.85   0.505547
# 5  resnet50        rot90      10      0.80   0.680915
#
#                              weights_path
# 2     models/e3_alexnet_bright.weights.h5
# 3   models/e3_alexnet_contrast.weights.h5
# 0       models/e3_alexnet_flip.weights.h5
# 1      models/e3_alexnet_rot90.weights.h5
# 6    models/e3_resnet50_bright.weights.h5
# 7  models/e3_resnet50_contrast.weights.h5
# 4      models/e3_resnet50_flip.weights.h5
# 5     models/e3_resnet50_rot90.weights.h5
